# %%
import pandas as pd
import re
from lxml import etree
import shutil
import os
import math
import copy
import glob

# %%
#19-32
#113-128 chnaged the typos?
#491-504

# %%
def load_base_value_iden(file_path):
    if os.path.exists(file_path):
        
        # File exists, load the variable from the file
        if os.path.getsize(file_path) > 0:
                    # File is not empty, load the variable from the file
            with open(file_path, 'r') as file:
                
                variable_loaded = file.read().strip()
#                 print('loading')
#                 print(variable_loaded)
        else:
            # File exists but is empty, initialize with a default value
            variable_loaded = "11e1d6e4-74ba-49cc-9b55-1"
    else:
        # File does not exist, create the file and write the variable to it
#         print('+++++')
        print('creating file...')
        variable_to_store = "11e1d6e4-74ba-49cc-9b55-1"
        with open(file_path, 'w') as file:
            file.write(variable_to_store)
        variable_loaded = variable_to_store
        
    return variable_loaded
def save_base_value_iden(file_path,variable_to_store):
    
    # Write the variable to the file
    with open(file_path, 'w') as file:
        file.write(variable_to_store)
def increment_value_iden(value,file_path):

    str_last = value.split('-')[-1]
    last= int(str_last)
    last+=1
    
    exclude_last = value.split('-')[:-1]
    temp = '-'.join(exclude_last)

    new_identifier = temp + '-' + str(last)
    
    if os.path.exists(file_path):
        with open(file_path, 'w') as file:
            variable_to_store = new_identifier
#             print('writing')
#             print(variable_to_store)
            file.write(variable_to_store)
    else:
        print('load base value first')
def adjust_identifier(root_copy,filepath_base_identifier):
    base_identifier = load_base_value_iden(filepath_base_identifier)

    for index,e in enumerate(root_copy.iter()):
        if index == 10:#rsender identifier:
            e.text = base_identifier
            increment_value_iden(base_identifier,filepath_base_identifier)
def get_element_xpath(element):
    path = [element.tag.split('}')[-1]]
    for parent in element.iterancestors():
        parent_tag = parent.tag.split('}')[-1]  
        path.insert(0, parent_tag)
    return ' / '.join(path)
def read_xml_file(file_path_xml):
    result_xml_dict={}
    tree = etree.parse(file_path_xml)
    target_root = tree.getroot()
#     pattern = r'\{.*?\}'
    for element in target_root.iter():
        if element.attrib:
            xpath_base = get_element_xpath(element)
            for e,val in element.attrib.items():
                xpath = xpath_base + ' / ' + '@' + e
#                 print(f'-->{xpath}')
                result_xml_dict[xpath] = tree.getpath(element)
        else:
            xpath = get_element_xpath(element)
            result_xml_dict[xpath] = tree.getpath(element)
    return result_xml_dict
        
def get_element_full_path(tree,element):
    return tree.getpath(element)

def read_xml_file_2(file_path_xml):
    tree = etree.parse(file_path_xml)
    target_root = tree.getroot()
    for element in target_root.iter():
        xpath = tree.getpath(element)
        print(f"XPath: {xpath}")
def get_mapping_for_xml_invoice(file_path_of_sample_xml):

    namespace_map = {
        'sb': 'http://www.unece.org/cefact/namespaces/StandardBusinessDocumentHeader',
        'xs': 'http://www.w3.org/2001/XMLSchema',
        'cac': 'urn:oasis:names:specification:ubl:schema:xsd:CommonAggregateComponents-2',
        'cbc': 'urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2',
        'ubl': 'urn:oasis:names:specification:ubl:schema:xsd:Invoice-2',
        'xsi': "http://www.w3.org/2001/XMLSchema-instance",
        'xsd':"http://www.w3.org/2001/XMLSchema",
        'udt':"urn:un:unece:uncefact:data:specification:UnqualifiedDataTypesSchemaModule:2" ,
        'qdt':"urn:oasis:names:specification:ubl:schema:xsd:QualifiedDatatypes-2",
        'ext':"urn:oasis:names:specification:ubl:schema:xsd:CommonExtensionComponents-2",
        'ccts':"urn:un:unece:uncefact:documentation:2"
    #     'xmlns' : "urn:oasis:names:specification:ubl:schema:xsd:Invoice-2"
    }
    tree = etree.parse(file_path_of_sample_xml)
    target_root = tree.getroot()
    # format_key_map = []
    invoice_dict={}
    for element in target_root.iter():
        ancestors = [e.tag for e in element.iterancestors()][::-1] + [element.tag]

        string_ancestors = [e if isinstance(e, str) else str(e) for e in ancestors]

        path = ' / '.join(string_ancestors)
        for prefix, uri in namespace_map.items():
            path = path.replace('{' + uri + '}', prefix + ':')
        if 'sb:StandardBusinessDocument / ubl:Invoice / ' in path:
            path = path.replace('sb:StandardBusinessDocument / ', '')
            if element.attrib:
                xpath_base = path
                invoice_dict[xpath_base] = tree.getpath(element)
                for e,val in element.attrib.items():
                    xpath = xpath_base + ' / ' + '@' + e

                    invoice_dict[xpath] = tree.getpath(element)
            else:
                invoice_dict[path] = tree.getpath(element)

        else:
            if element.attrib:
                xpath_base = get_element_xpath(element)
                invoice_dict[xpath_base] = tree.getpath(element)
                for e,val in element.attrib.items():
                    xpath = xpath_base + ' / ' + '@' + e
    #                 print(f'-->{xpath}')
                    invoice_dict[xpath] = tree.getpath(element)
            else:
                xpath = get_element_xpath(element)#defined on top
                invoice_dict[xpath] = tree.getpath(element)
    r_h = invoice_dict
    return r_h
def get_mapping_for_xml_credit(file_path_of_sample_xml):
    namespace_map = {
        'sb': 'http://www.unece.org/cefact/namespaces/StandardBusinessDocumentHeader',
        'xs': 'http://www.w3.org/2001/XMLSchema',
        'cac': 'urn:oasis:names:specification:ubl:schema:xsd:CommonAggregateComponents-2',
        'cbc': 'urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2',
        'ubl': 'urn:oasis:names:specification:ubl:schema:xsd:CreditNote-2',
        'xsi': "http://www.w3.org/2001/XMLSchema-instance",
        'xsd':"http://www.w3.org/2001/XMLSchema",
        'udt':"urn:un:unece:uncefact:data:specification:UnqualifiedDataTypesSchemaModule:2" ,
        'qdt':"urn:oasis:names:specification:ubl:schema:xsd:QualifiedDatatypes-2",
        'ext':"urn:oasis:names:specification:ubl:schema:xsd:CommonExtensionComponents-2",
        'ccts':"urn:un:unece:uncefact:documentation:2" 
    }
    tree = etree.parse(file_path_of_sample_xml)
    target_root = tree.getroot()
        # format_key_map = []
    credit_dict={}
    for element in target_root.iter():
        if isinstance(element, etree._Comment):
            continue

        else:
            ancestors = [e.tag for e in element.iterancestors()][::-1] + [element.tag]

            string_ancestors = [e if isinstance(e, str) else str(e) for e in ancestors]

            path = ' / '.join(string_ancestors)
            for prefix, uri in namespace_map.items():
                path = path.replace('{' + uri + '}', prefix + ':')

            if 'sb:StandardBusinessDocument / ubl:CreditNote / ' in path:

                path = path.replace('sb:StandardBusinessDocument / ', '')

                if element.attrib:
                    xpath_base = path
                    credit_dict[xpath_base] = tree.getpath(element)
                    for e,val in element.attrib.items():
                        xpath = xpath_base + ' / ' + '@' + e

                        credit_dict[xpath] = tree.getpath(element)
                else:
                    credit_dict[path] = tree.getpath(element)

            else:
                if element.attrib:
                    xpath_base = get_element_xpath(element)
                    credit_dict[xpath_base] = tree.getpath(element)
                    for e,val in element.attrib.items():
                        xpath = xpath_base + ' / ' + '@' + e
        #                 print(f'-->{xpath}')
                        credit_dict[xpath] = tree.getpath(element)
                else:
                    xpath = get_element_xpath(element)#defined on top
                    credit_dict[xpath] = tree.getpath(element)
    c_h = credit_dict
    return c_h
def credit_or_invoice(file_path):
#     print('********')
#     print(file_path)
    tree = etree.parse(file_path)
    target_root = tree.getroot()
    for index,e in enumerate(target_root.iter()):
        if index ==11:
            if 'Credit' in e.text:
                return 'credit'
            elif 'Invoice' in e.text:
                return 'invoice'
            else:
                return 'undefined'
def proper_mapping_final(file_path):

    if credit_or_invoice(file_path) == 'credit':
        r_h = get_mapping_for_xml_credit(file_path)
        return r_h
    elif credit_or_invoice(file_path) == 'invoice':
        r_h = get_mapping_for_xml_invoice(file_path)
        return r_h
    else:
        return None
def adjust_customisation_id(root_copy,value):
     for index,e in enumerate(root_copy.iter()):
        if index == 31:
            print("----")
            print("--customisation--")
            print("  ")
            print(f'{e} element text ->{e.text}')
            e.text = value
            print("  ")
            print("----")
            print("----")

            
        
def adjust_profile_id(root_copy,value):
    for index,e in enumerate(root_copy.iter()):
        if index == 33:
            print("----")
            print("--profile--")
            print("  ")
            print(f'{e} element text ->{e.text}')
            e.text = value
            print("  ")
            print("----")
            print("----")


def insert_for_attribute(target_element,insert_value,each_path):
    print('   ')
    print('------change attrib------')
    if len(target_element)>0:

        print(f'----<<--actual element value==>{target_element[0].attrib} type = {type(target_element[0].attrib)}')
        for key, value in target_element[0].attrib.items():
            print(f'val = {value}')
            target_element[0].attrib[key] = insert_value
        print(f'----<<--new attribute value==>{target_element[0].attrib}')

    else:
         print(f'--cannot get--<<--{each_path} | {target_element} is empty ')
    return target_element
def insert_for_element(target_element,insert_value,each_path):
    print('   ')
    print('------change element------')
    if len(target_element)>0:
        print(f'----<<--actual element text==>{target_element[0].text}')
        target_element[0].text = insert_value
        
        print(f'----<<--new element text==>{target_element[0].text}')
    else:
         print(f'---cannot get-<<--{each_path} | {target_element} is empty ')
    return target_element

def handle_descriptions(desc,index):#like a custom immigration gate,right before writng to file,remove if element
    if 'Field does not exist' in desc and index==0:
        print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
        print('                                   ')
        
        print('RUMBLE')
        
        print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
        print('                                   ')
    else:
        pass
#still there
#takes in desc and fieldone path.resolves into xpath
#remove element if still there at the end for filed does not exist
#change from 'nan' to '' if field exist with missingn value,adjust value_store first element as thats waht
#field description is referring to

def  delete_element_attrib(desc,target_root_copy,actual_xpath_absolute,r_h,each_path):
    attrib_yes = False
  
    if '@' in each_path:
        attrib_yes = True
        
    if 'Field does not exist' in desc:
        print(f'%%%%%%%%xpath find{actual_xpath_absolute} %%%%%%%%')
        print('                 ')
        print('Targeting element......')
        element_temp = target_root_copy.xpath(actual_xpath_absolute, namespaces=namespace_map)
        if len(element_temp)>0:
            element = element_temp[0]
            if attrib_yes:
                print(f'%%%%%%%% current attrib {element.attrib} %%%%%%%%')
                del element.attrib[key_attrib]
                print(f'%%%%%%%% new  attrib {element.attrib} %%%%%%%%')
#                 key_attrib = xpath_find.split('@')[-1]
#                 print(f'removing attrib {xpath_find}')
#                 print(f'%%%%%%%% current attrib {element.attrib} %%%%%%%%')
#                 del element.attrib[key_attrib]
#                 print(f'%%%%%%%% new  attrib {element.attrib} %%%%%%%%')
            else:
                print('%%%%%%%% Remove element %%%%%%%%')
                parent = element.getparent()

                if element.getparent() is not None:
                    element.getparent().remove(element)

                print('------------')
        else:
            print('xpath ')
        return target_root_copy
    else:
        print('%%%%%%%%%%%%%%%%')
        print('                  ')
        return target_root_copy


def extract_out_second_half(actual_xpath):#to be attachrd to path_base
    temp = actual_xpath.split('/')[-1]
    return temp
def handle_base_path(s):
    start = r_h[s]
#     print(f'start {start}')
    a= start
    specific_elem = a.split('/')[-1]
#     print(f'specific elem{specific_elem}')
    temp = a.split('/')[:-1]
#     print('temp',temp)
    temp_a = '/'.join(temp)
#     print('temp_a',temp_a)

    temp_b = temp[-1].split('[')[0]
    temp_c = temp
    temp_c[-1] = temp_b
    temp_d = '/'.join(temp_c)
#     print('temp_d',temp_d)
#     print('   ')
    return temp_d
            
def evaluate_if_got_multiple(current_test_case):
    occur_again = False
    for index,fields in enumerate(current_test_case):
        xpath_find = fields[0].strip()
        if index == 0:
            field_one = xpath_find
        if (xpath_find == field_one) and index != 0:
            occur_again = True
            return True
    return occur_again
def prepare_data_for_multiple(current_test_case):
    holding = []
    values_store=[]
    for index,fields in enumerate(current_test_case):
        
        path_to_store = fields[0]
        value = fields[1]
        values_store.append(value)
        if index == 0:
            temp = []
            
            field_one = path_to_store
            temp.append(path_to_store)
            
        elif (path_to_store == field_one) and (index != 0):
            holding.append(temp)
            temp = []

        
            temp.append(path_to_store)
        else:
#             print('  ----  ')
#             print('    ')
#             print(temp)
#             print('  ----  ')
#             print('    ')
            temp.append(path_to_store)
    holding.append(temp)
    return holding , values_store

def fix_space_typo(temp):
    temp_2 = temp.split("/")
    for index,i in enumerate(temp_2):
        temp_2[index] = i.strip()
    temp_3 = ' / '.join(temp_2)
    return temp_3

# %%
output_folder = '/Users/cheongray/iras_api_clean_1/2_Conditional_Validation'
os.makedirs(output_folder, exist_ok=True)  # Create folder if it doesn't exist

output_file = os.path.join(output_folder, 'df_full.csv')
output_file_original = os.path.join(output_folder, 'df_full_back_up.csv')
if os.path.exists(output_file):
    os.remove(output_file)
if os.path.exists(output_file_original):
    os.remove(output_file_original)

# %%
file_path = r"/Users/cheongray/iras_api_pytest_1/AP_SP_files/AP_SP_FINAL_5.xlsx"
sheet_name = '2_Conditional Input Validation'

path_to_sample_xml_files_folder = r"/Users/cheongray/iras_api_clean_1/sample_xml_files"


df_s = pd.read_excel(file_path, sheet_name=sheet_name)
df_s_temp = df_s.copy()
df_s_temp['Test Case ID'] = df_s_temp.index.astype(float)#REMINDER,now test_case_id is 1_1
# df_s_peppol = df_s_temp[(df_s_temp['Standard'] == 'PEPPOL') & (df_s_temp['Document Type'] == 'Invoice')].copy()
# df_s_peppol['Test Case ID'] = df_s_peppol['Test Case ID'] + 1
# df_s_peppol.reset_index(drop=True)
df_s_temp['Test Case ID'] = df_s_temp['Test Case ID'] + 1
df_s_temp.to_csv(output_file, index=False)
df_s_temp.to_csv(output_file_original, index=False)

# %%
df_s_temp_subset = df_s_temp.copy()

unique_descriptions = set()

target_elements_syn = []

for index,row in df_s_temp_subset.iterrows():
    filled_columns = row.dropna().index
    test_case_id = f' {index}'
    descript = row['Test Case Description']
#     print(f'Test case {index+1}')
#     print(f'Test case description : {descript}')
    unique_descriptions.add(descript)#just to build function_mapping
    temp={}
    temp['Rule ID'] = row['Rule ID']
    temp['Standard'] = row['Standard']
    temp['Document Type'] = row['Document Type']
    temp['BIS/PINT'] = row['BIS/PINT']
    temp['Test Case ID'] = int(row['Test Case ID'])
    temp['descript'] = descript
    temp['Expected Result'] = row['Expected Result Response (for 400 response)']
    temp['Status'] = row['Expected Result']
    temp['Fields'] = []
    temp['Sample'] = row['Sample']
    for i, col in enumerate(filled_columns, start=1):
        field_name = f'Field {i}'
        
        if field_name in df_s_temp_subset.columns:
            # Process the data as needed
#             print(f'Column: {field_name}, Value: {row[field_name]}')
   
            
            temp_2 = [] #each field will be one array,can do dict but mor steps when want access
            if not pd.isna(row[field_name]):
                
                field_value = field_name + ' Value'
                temp_2.append(fix_space_typo(row[field_name]))
                temp_2.append(row[field_value])
                temp['Fields'].append(temp_2)
        
    target_elements_syn.append(temp)

# %%
# path_to_sample_xml_files = '/Users/cheongray/iras_api_pytest_1/sample_xml_files'
#gets the needed files for 2_Conditional_Input_Validation
file_paths_xml_files = {}

for i,test_case in enumerate(target_elements_syn):
    sample_to_use = test_case['Sample']

    num = sample_to_use[-1]
    file_name = 'sample' + '_' + str(num) + '.xml'
    
    path_to_sample_xml_files = path_to_sample_xml_files_folder + '/' + file_name
    
    file_paths_xml_files[sample_to_use] = path_to_sample_xml_files

# %%
load_base_value_iden(filepath_base_identifier)
save_base_value_iden(filepath_base_identifier,'11checking_test-74ba-49cc-9b55-1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 load_base_value_iden(filepath_base_identifier)
#       2 save_base_value_iden(filepath_base_identifier,'11checking_test-74ba-49cc-9b55-1')
#
# NameError: name 'filepath_base_identifier' is not defined

# %%
folder_name = output_folder + '/xml_files_for'+'_'+sheet_name

filepath_base_identifier = '/Users/cheongray/iras_api_make_xml/identifier_store/stored_base_identifier_conditional_validation.txt'

# save_base_value_iden(filepath_base_identifier,'11e1d6e4-74ba-49cc-9b55-1')
namespace_map = {
    'sb': 'http://www.unece.org/cefact/namespaces/StandardBusinessDocumentHeader',
    'xs': 'http://www.w3.org/2001/XMLSchema',
    'cac': 'urn:oasis:names:specification:ubl:schema:xsd:CommonAggregateComponents-2',
    'cbc': 'urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2',
    }



function_mapping = {
    'Field exists with missing value':0,
    'Field does not exist': 1
}


def handle_multiple(current_test_case,test_case_id,r_h,target_root,desc):
    print(f' {test_case_id}  ')
    whole_count_pos = 0
    hold_1 , value_store = prepare_data_for_multiple(current_test_case)
    print('------------')
    print(hold_1)
    print('   ')
    field_1 = hold_1[0][0]
    base_path_field_1 = handle_base_path(field_1)

    print('   ')
    value_store_key = 0
    temp_base_path = base_path_field_1
    target_root_copy = copy.deepcopy(target_root)
    for index,each_case in enumerate(hold_1):
        
        

        path_base = temp_base_path + f'[{index+1}]' + '/'
        

        for each_path in each_case:
            
            print('+++++++++++++++++++++++++')
            

            
            insert_value = str(value_store[value_store_key])
            print('+++++++++++++++++++++++++')
            print('---------------')
            print('   ')
            
            print(f'insert value = {value_store[value_store_key]}')
            if 'missing value' in desc and value_store_key == 0:
                
                print(f'old insert value {insert_value} type is {type(insert_value)} id is {value_store_key}')
                print(f'##Description = {desc}##')
                insert_value = ''
                print(f'new insert value {insert_value}')
            value_store_key +=1
        
            print(f'value_store_key === > {value_store_key}')
            print(' ')
            base_path_each_path = handle_base_path(each_path)

            if base_path_each_path == base_path_field_1:

                print('   ')
                print(f'----<<--Ammend base path for {each_path} ->>-----')
#                 if each_path == field_1 and whole_count_pos==0:
#                     print(']]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]')
#                     print(f'each_path {each_path} ')
#                     target_root_copy = delete_element_attrib(desc,target_root_copy,each_path,r_h)
#                 print('   ')
                if each_path in r_h:
                    actual_xpath = r_h[each_path]
                    temp = extract_out_second_half(actual_xpath)
                    actual_xpath_absolute = path_base + temp
                    print(f'----<<--actual amended base path ==>{actual_xpath_absolute}')
                    target_element = target_root_copy.xpath(actual_xpath_absolute,namespaces = namespace_map)

                    print(f'----<<--actual path {each_path} index == {whole_count_pos}')
                    if '@' in each_path:
                        print(f'target element ==>{target_element}')
                        print(f'>>>>>>target_element.attrib = {target_element[0].attrib}')
                        print(f'>>>>>>target_element.text = {target_element[0].text}')
                        target_element = insert_for_attribute(target_element,insert_value,each_path)
                        print('             ')
                        
                        print('   ')
                    else:
                        target_element = insert_for_element(target_element,insert_value,each_path)
                    if whole_count_pos == 0:
                        print(']]]]]]]]]]]]]]]]]base_path_each_path == base_path_field_1]]]]]]]]]]]]]]]]]]')
                        print(f'each path = {each_path}')
                        print(f'{actual_xpath_absolute}')
                        target_root_copy = delete_element_attrib(desc,target_root_copy,actual_xpath_absolute,r_h,each_path)
                        print('<<<<last>>>')
      

            else:#base_path_each_path != base_path_field_1:
                    print('   ')
                    print(f'----<<--just change straight away {each_path} index == {whole_count_pos}->>')
                    print('   ')
                    if each_path in r_h:
                        actual_xpath = r_h[each_path]
                    target_element = target_root_copy.xpath(actual_xpath,namespaces = namespace_map)
                    print('    ')
                    print('===============')
                    print(f'acutal path : {actual_xpath}')
                    
                    
                    print('   ')
                    if '@' in each_path:
                        print('   ')
                        print(f'target element {target_element}')
                        print('------change attrib------')
                        target_element = insert_for_attribute(target_element,insert_value,each_path)
                       
                        print('   ')
                    else:
                        print('   ')
                        print(f'target element {target_element}')
                        print('------change element------')
                        target_element = insert_for_element(target_element,insert_value,each_path)
                        

                        print('   ')
                    if whole_count_pos == 0:
                        print(']]]]]]]]]]]]]]]base_path_each_path != base_path_field_1]]]]]]]]]]]]]]]]]]]]')
                        print(f'each path = {each_path}')
                        print(f'{actual_xpath_absolute}')
                        target_root_copy = delete_element_attrib(desc,target_root_copy,actual_xpath,r_h)
                        print('<<<<last>>>')
#             if whole_count_pos == 0:

#                 print(f'{each_path}')
#                 print(f'{ea}')
#                 if '@' in each_path:
#                     pass
#                 print('<<<<last>>>')
            whole_count_pos += 1
  
    

    print('   ')
    print('             ')
    print(value_store_key)
    print('             ')
    print(value_store)
    return target_root_copy


#[['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 'ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID']
#, ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 'ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'ubl:Invoice / cbc:DocumentCurrencyCode', 'ubl:Invoice / cbc:TaxCurrencyCode']]   
    






if not os.path.exists(folder_name):
    os.makedirs(folder_name)
if os.path.exists(folder_name):
    shutil.rmtree(folder_name)
    os.makedirs(folder_name)
    
    
    



KEY_NOT_FOUND=[]
elements_to_remove = []
error_prone_multiple = []
for i,test_case in enumerate(target_elements_syn):
    
#     current_test_case = test_case['Fields']
#     test_case_id = test_case['Test Case ID']
#     desc = test_case['descript']
#     sample_to_use = test_case['Sample']
#     rule_id = test_case['Rule ID']
        
    current_test_case = test_case['Fields']
    test_case_id = test_case['Test Case ID']

    print('############=================############')
    print(f'TEST CAES ID {test_case_id}')
    
    print('############=================############')

    desc = test_case['descript']
    sample_to_use = test_case['Sample']
    standard  = test_case['Standard']
    biz_pint = test_case['BIS/PINT']
    rule_id = test_case['Rule ID']
    
    
    f_p = file_paths_xml_files[sample_to_use]
    
    print(f'using {f_p}')
    print('   ')
    r_h = proper_mapping_final(f_p)
    
    if not r_h:
        print(f'cannot make r_h : {test_case_id}  sample :{sample_to_use}')
        continue
    tree = etree.parse(f_p)
    target_root = tree.getroot()
#     print(f'test case id :{test_case_id}')
#     print(desc)
    original_tree_copy = copy.deepcopy(target_root)
    if standard == 'PEPPOL':
        if biz_pint == 'BIS':
            value = 'urn:fdc:peppol.eu:2017:poacc:billing:01:1.0'
            adjust_profile_id(original_tree_copy,value)
            value_cus = 'urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0'
            adjust_customisation_id(original_tree_copy,value_cus)

        if biz_pint == 'PINT':
            value = 'urn:peppol:bis:billing'
            adjust_profile_id(original_tree_copy,value)
            value_cus = 'urn:peppol:pint:billing-1@sg-1'
            adjust_customisation_id(original_tree_copy,value_cus)


    if standard == 'Non-PEPPOL':
        if biz_pint == 'BIS':
            value = 'urn:fdc:peppol.eu:2017:poacc:billing:01:1.0'
            adjust_profile_id(original_tree_copy,value)
            value_cus = 'urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:LocalTaxInvoice:sg:1.0'
            adjust_customisation_id(original_tree_copy,value_cus)

        if biz_pint == 'PINT':
            value = 'urn:peppol:bis:billing'
            adjust_profile_id(original_tree_copy,value)
            value_cus = 'urn:peppol:pint:billing-1@sg-1:LocalTaxInvoice:sg:1.0'
            adjust_customisation_id(original_tree_copy,value_cus)
            
            
            
            
    adjust_identifier(original_tree_copy,filepath_base_identifier)
    lenght_of_fields = len(current_test_case)
    occur_again = evaluate_if_got_multiple(current_test_case)
    if not occur_again:
        print('CURRENT TEST CASE')
        print(current_test_case)
        for index,fields in enumerate(current_test_case):

            attrib_yes = False
            xpath_find = fields[0].strip()
            
            field_value = str(fields[1])
            print('++++++++++++++++++')
            print('++++++++bododododo++++++++++')
            if pd.isna(fields[1]) and 'does not exist' not in desc and 'missing value' not in desc:
                print(f'hulala back boi')
                field_value = 'NA'
                print(field_value)
       
            if '@' in xpath_find:
                    attrib_yes = True
            
            if 'does not exist' in desc and index == 0:
                if '@' in xpath_find:
                    print('why look at u youre an attribute')
                remove_element_flag = True
                print(f'xpath_find{xpath_find} |||||||')
                print('    ')
                temp = []
                if xpath_find in r_h:
                    xpath_target = r_h[xpath_find]
                else:
                    print(f'while trying to find xpath targtet to store in elements_to_remove,could not find key {xpath_find}')
                elements_to_remove_file_name = rule_id +'_' + 'Test_case_' + str(test_case_id) + '_' + sheet_name + '.xml'
                temp.append(elements_to_remove_file_name)
                temp.append(xpath_find)
                temp.append(xpath_target)
                temp.append(f_p)
                elements_to_remove.append(temp)
            if 'missing value' in desc and index == 0:
                print(f'old insert value {field_value} type is {type(field_value)}')
                print('      ')
                print(f'id == {index}')
                print(f'##Description = {desc}##')
                field_value = ''
                print(f'new insert value {field_value}')   
            if xpath_find in r_h:
                xpath_target = r_h[xpath_find]
                if original_tree_copy.xpath(xpath_target, namespaces=namespace_map):
                    element = original_tree_copy.xpath(xpath_target, namespaces=namespace_map)[0]
                    if not attrib_yes:
                        print(f'-non multiple-->insert test case id{test_case_id}  fieled value-->{field_value} xpath=={xpath_target}')    
                        element.text = field_value
                    else:
                        key_attrib = xpath_find.split('@')[-1]
                        print(f'test case id{test_case_id}  key attrib -->{key_attrib}')
                        element.attrib[key_attrib] = field_value
                        print('                                           ')
                if 'does not exist' in desc and index == 0:

                        print('Targeting element......')
                        if xpath_find in r_h:
                            xpath_target = r_h[xpath_find]
                            element_temp = original_tree_copy.xpath(xpath_target, namespaces=namespace_map)
                            if len(element_temp)>0:
                                element = element_temp[0]
                                if attrib_yes:
                                    del element.attrib[key_attrib]
                                else:

                                    parent = element.getparent()

                                    if element.getparent() is not None:
                                        element.getparent().remove(element)
                            else:
                                print(' ')
                                print(f'element to be removed {element} does not exist')
            else:#+++
                temp=[]
                temp.append(f'test case:{test_case_id} | uses {sample_to_use} key not found for {xpath_find}')
                print(f'--->test case:{test_case_id} | uses {sample_to_use} key not found for {xpath_find}')
                KEY_NOT_FOUND.append(temp)
        target_root = original_tree_copy
    else:
        error_prone_multiple.append(test_case_id)
        target_root = handle_multiple(current_test_case,test_case_id,r_h,original_tree_copy,desc)
    tree = etree.ElementTree(target_root)
    indexed_filename =rule_id +'_' + 'Test_case_' + str(test_case_id) + '_' + sheet_name + '.xml'
    filepath = os.path.join(folder_name, indexed_filename)
    print(f'writing {filepath}')
    tree.write(filepath, encoding='utf-8', xml_declaration=True)
# Out:
# ############=================############
# TEST CAES ID 1
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x14243d400> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x14243d400> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', 'SGD'], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id1  fieled value-->SGD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id1  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_1_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 2
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142a07240> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142a07240> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', 'SGD'], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id2  fieled value-->SGD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id2  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_2_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 3
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142add980> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142b01d40> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', 'USD'], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id3  fieled value-->USD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id3  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_3_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 4
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x137d5dec0> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x14243d840> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', 'USD'], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id4  fieled value-->USD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id4  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_4_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 5
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adc580> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x137cf6080> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', nan], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# old insert value nan type is <class 'str'>
#
# id == 0
# ##Description = Field exists with missing value when document currency code != SGD##
# new insert value
# -non multiple-->insert test case id5  fieled value--> xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id5  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_5_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 6
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x137d5ee40> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142a05200> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', nan], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# old insert value nan type is <class 'str'>
#
# id == 0
# ##Description = Field exists with missing value when document currency code = SGD##
# new insert value
# -non multiple-->insert test case id6  fieled value--> xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id6  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_6_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 7
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adef00> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x137cf6740> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', nan], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# xpath_findubl:Invoice / cbc:TaxCurrencyCode |||||||
#
# -non multiple-->insert test case id7  fieled value-->nan xpath==/*/*[2]/cbc:TaxCurrencyCode
# Targeting element......
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id7  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_7_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 8
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x137d5d440> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142a05200> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', nan], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# xpath_findubl:Invoice / cbc:TaxCurrencyCode |||||||
#
# -non multiple-->insert test case id8  fieled value-->nan xpath==/*/*[2]/cbc:TaxCurrencyCode
# Targeting element......
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id8  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_8_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 9
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adf5c0> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142b04340> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', 'SGD'], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id9  fieled value-->SGD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id9  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_9_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 10
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142a076c0> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142a076c0> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', 'SGD'], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id10  fieled value-->SGD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id10  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_10_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 11
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adc440> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142a05780> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', 'USD'], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id11  fieled value-->USD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id11  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_11_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 12
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142a076c0> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142b01d40> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', 'USD'], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id12  fieled value-->USD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id12  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_12_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 13
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adef00> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x137d5dec0> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', nan], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# old insert value nan type is <class 'str'>
#
# id == 0
# ##Description = Field exists with missing value when document currency code != SGD##
# new insert value
# -non multiple-->insert test case id13  fieled value--> xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id13  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_13_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 14
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142b37d00> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142b01d40> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', nan], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# old insert value nan type is <class 'str'>
#
# id == 0
# ##Description = Field exists with missing value when document currency code = SGD##
# new insert value
# -non multiple-->insert test case id14  fieled value--> xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id14  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_14_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 15
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adc680> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x14243d280> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', nan], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# xpath_findubl:Invoice / cbc:TaxCurrencyCode |||||||
#
# -non multiple-->insert test case id15  fieled value-->nan xpath==/*/*[2]/cbc:TaxCurrencyCode
# Targeting element......
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id15  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_15_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 16
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adee00> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142afec80> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', nan], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# xpath_findubl:Invoice / cbc:TaxCurrencyCode |||||||
#
# -non multiple-->insert test case id16  fieled value-->nan xpath==/*/*[2]/cbc:TaxCurrencyCode
# Targeting element......
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id16  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_16_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 17
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adc340> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x137d5dec0> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', 'SGD'], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id17  fieled value-->SGD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id17  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_17_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 18
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142ade740> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142b37d00> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', 'SGD'], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id18  fieled value-->SGD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id18  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_18_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 19
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adfb80> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142a04f80> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', 'USD'], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id19  fieled value-->USD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id19  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_19_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 20
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142ade740> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142ade740> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', 'USD'], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id20  fieled value-->USD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id20  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_20_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 21
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adc740> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142adc740> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', nan], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# old insert value nan type is <class 'str'>
#
# id == 0
# ##Description = Field exists with missing value when document currency code != SGD##
# new insert value
# -non multiple-->insert test case id21  fieled value--> xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id21  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_21_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 22
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142ade440> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142ade440> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', nan], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# old insert value nan type is <class 'str'>
#
# id == 0
# ##Description = Field exists with missing value when document currency code = SGD##
# new insert value
# -non multiple-->insert test case id22  fieled value--> xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id22  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_22_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 23
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142ade040> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142ade040> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', nan], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# xpath_findubl:Invoice / cbc:TaxCurrencyCode |||||||
#
# -non multiple-->insert test case id23  fieled value-->nan xpath==/*/*[2]/cbc:TaxCurrencyCode
# Targeting element......
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id23  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_23_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 24
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adc680> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142adc680> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', nan], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# xpath_findubl:Invoice / cbc:TaxCurrencyCode |||||||
#
# -non multiple-->insert test case id24  fieled value-->nan xpath==/*/*[2]/cbc:TaxCurrencyCode
# Targeting element......
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id24  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_24_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 25
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adc5c0> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142adc5c0> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', 'SGD'], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id25  fieled value-->SGD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id25  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_25_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 26
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adef00> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142adef00> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', 'SGD'], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id26  fieled value-->SGD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id26  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_26_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 27
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adc740> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142adc740> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', 'USD'], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id27  fieled value-->USD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id27  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_27_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 28
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adc240> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142adc240> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', 'USD'], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id28  fieled value-->USD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id28  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_28_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 29
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142ade5c0> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142ade5c0> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', nan], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# old insert value nan type is <class 'str'>
#
# id == 0
# ##Description = Field exists with missing value when document currency code != SGD##
# new insert value
# -non multiple-->insert test case id29  fieled value--> xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id29  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_29_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 30
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adf100> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142adf100> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', nan], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# old insert value nan type is <class 'str'>
#
# id == 0
# ##Description = Field exists with missing value when document currency code = SGD##
# new insert value
# -non multiple-->insert test case id30  fieled value--> xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id30  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_30_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 31
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adeac0> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142adeac0> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', nan], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# xpath_findubl:Invoice / cbc:TaxCurrencyCode |||||||
#
# -non multiple-->insert test case id31  fieled value-->nan xpath==/*/*[2]/cbc:TaxCurrencyCode
# Targeting element......
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id31  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_31_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 32
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_2.xml
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x137d7e900> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x137494dc0> element text ->urn:cen.eu:en16931:2017#conformant#urn:fdc:peppol.eu:2017:poacc:billing:international:sg:3.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:Invoice / cbc:TaxCurrencyCode', nan], ['ubl:Invoice / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# xpath_findubl:Invoice / cbc:TaxCurrencyCode |||||||
#
# -non multiple-->insert test case id32  fieled value-->nan xpath==/*/*[2]/cbc:TaxCurrencyCode
# Targeting element......
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id32  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_32_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 33
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_4.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x14243d840> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x137cf5980> element text ->urn:peppol:pint:billing-1@sg-1:LocalTaxInvoice:sg:1.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:CreditNote / cbc:TaxCurrencyCode', 'SGD'], ['ubl:CreditNote / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id33  fieled value-->SGD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id33  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_33_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 34
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_4.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142a076c0> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142b818c0> element text ->urn:peppol:pint:billing-1@sg-1:LocalTaxInvoice:sg:1.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:CreditNote / cbc:TaxCurrencyCode', 'SGD'], ['ubl:CreditNote / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id34  fieled value-->SGD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id34  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_34_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 35
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_4.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adc280> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x137d5ee40> element text ->urn:peppol:pint:billing-1@sg-1:LocalTaxInvoice:sg:1.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:CreditNote / cbc:TaxCurrencyCode', 'USD'], ['ubl:CreditNote / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id35  fieled value-->USD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id35  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_35_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 36
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_4.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142a05b00> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142b818c0> element text ->urn:peppol:pint:billing-1@sg-1:LocalTaxInvoice:sg:1.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:CreditNote / cbc:TaxCurrencyCode', 'USD'], ['ubl:CreditNote / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id36  fieled value-->USD xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id36  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_36_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 37
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_4.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142adfb80> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142a07600> element text ->urn:peppol:pint:billing-1@sg-1:LocalTaxInvoice:sg:1.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:CreditNote / cbc:TaxCurrencyCode', nan], ['ubl:CreditNote / cbc:DocumentCurrencyCode', 'USD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# old insert value nan type is <class 'str'>
#
# id == 0
# ##Description = Field exists with missing value when document currency code != SGD##
# new insert value
# -non multiple-->insert test case id37  fieled value--> xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id37  fieled value-->USD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_37_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 38
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_4.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142a05780> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x14243c1c0> element text ->urn:peppol:pint:billing-1@sg-1:LocalTaxInvoice:sg:1.0
#
# ----
# ----
# CURRENT TEST CASE
# [['ubl:CreditNote / cbc:TaxCurrencyCode', nan], ['ubl:CreditNote / cbc:DocumentCurrencyCode', 'SGD']]
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# old insert value nan type is <class 'str'>
#
# id == 0
# ##Description = Field exists with missing value when document currency code = SGD##
# new insert value
# -non multiple-->insert test case id38  fieled value--> xpath==/*/*[2]/cbc:TaxCurrencyCode
# ++++++++++++++++++
# ++++++++bododododo++++++++++
# -non multiple-->insert test case id38  fieled value-->SGD xpath==/*/*[2]/cbc:DocumentCurrencyCode
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-014_Test_case_38_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 39
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_4.xml
#
# ----
# --profile--
#
# ...
# insert value = SGD
# value_store_key === > 6
#
#
# ----<<--just change straight away ubl:CreditNote / cbc:TaxCurrencyCode index == 5->>
#
#
# ===============
# acutal path : /*/*[2]/cbc:TaxCurrencyCode
#
#
# target element [<Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142accb00>]
# ------change element------
#
# ------change element------
# ----<<--actual element text==>SGD
# ----<<--new element text==>SGD
#
#
#
# 6
#
# ['SGD', 1000, 'USD', 600, 'USD', 'SGD']
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-038_Test_case_213_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 214
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_4.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142acd400> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142acf500> element text ->urn:peppol:pint:billing-1@sg-1:LocalTaxInvoice:sg:1.0
#
# ----
# ----
#  214
# ------------
# [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount'], ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 'ubl:CreditNote / cbc:DocumentCurrencyCode', 'ubl:CreditNote / cbc:TaxCurrencyCode']]
#
#
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = XXX
# value_store_key === > 1
#
#
# ----<<--Ammend base path for ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID ->>-----
# ----<<--actual amended base path ==>/*/*[2]/cac:TaxTotal[1]/cbc:TaxAmount
# ----<<--actual path ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID index == 0
# target element ==>[<Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxAmount at 0x142acf500>]
# >>>>>>target_element.attrib = {'currencyID': 'SGD'}
# >>>>>>target_element.text = 2374.05
#
# ------change attrib------
# ----<<--actual element value==>{'currencyID': 'SGD'} type = <class 'lxml.etree._Attrib'>
# val = SGD
# ----<<--new attribute value==>{'currencyID': 'XXX'}
#
#
# ]]]]]]]]]]]]]]]]]base_path_each_path == base_path_field_1]]]]]]]]]]]]]]]]]]
# each path = ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID
# /*/*[2]/cac:TaxTotal[1]/cbc:TaxAmount
# %%%%%%%%%%%%%%%%
#
# <<<<last>>>
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = 1000
# value_store_key === > 2
#
#
# ----<<--Ammend base path for ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount ->>-----
# ----<<--actual amended base path ==>/*/*[2]/cac:TaxTotal[1]/cbc:TaxAmount
# ----<<--actual path ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount index == 1
#
# ------change element------
# ----<<--actual element text==>2374.05
# ----<<--new element text==>1000
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = USD
# value_store_key === > 3
#
#
# ----<<--Ammend base path for ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID ->>-----
# ----<<--actual amended base path ==>/*/*[2]/cac:TaxTotal[2]/cbc:TaxAmount
# ----<<--actual path ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID index == 2
# target element ==>[<Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxAmount at 0x142acff40>]
# >>>>>>target_element.attrib = {'currencyID': 'USD'}
# >>>>>>target_element.text = 2374.05
#
# ------change attrib------
# ----<<--actual element value==>{'currencyID': 'USD'} type = <class 'lxml.etree._Attrib'>
# val = USD
# ----<<--new attribute value==>{'currencyID': 'USD'}
#
#
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = 600
# value_store_key === > 4
#
#
# ----<<--Ammend base path for ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount ->>-----
# ----<<--actual amended base path ==>/*/*[2]/cac:TaxTotal[2]/cbc:TaxAmount
# ----<<--actual path ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount index == 3
#
# ------change element------
# ----<<--actual element text==>2374.05
# ----<<--new element text==>600
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = USD
# value_store_key === > 5
#
#
# ----<<--just change straight away ubl:CreditNote / cbc:DocumentCurrencyCode index == 4->>
#
#
# ===============
# acutal path : /*/*[2]/cbc:DocumentCurrencyCode
#
#
# target element [<Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}DocumentCurrencyCode at 0x142acf7c0>]
# ------change element------
#
# ------change element------
# ----<<--actual element text==>USD
# ----<<--new element text==>USD
#
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = SGD
# value_store_key === > 6
#
#
# ----<<--just change straight away ubl:CreditNote / cbc:TaxCurrencyCode index == 5->>
#
#
# ===============
# acutal path : /*/*[2]/cbc:TaxCurrencyCode
#
#
# target element [<Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142acde40>]
# ------change element------
#
# ------change element------
# ----<<--actual element text==>SGD
# ----<<--new element text==>SGD
#
#
#
# 6
#
# ['XXX', 1000, 'USD', 600, 'USD', 'SGD']
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-038_Test_case_214_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 215
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_4.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142accb00> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142acc400> element text ->urn:peppol:pint:billing-1@sg-1:LocalTaxInvoice:sg:1.0
#
# ----
# ----
#  215
# ------------
# [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount'], ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 'ubl:CreditNote / cbc:DocumentCurrencyCode', 'ubl:CreditNote / cbc:TaxCurrencyCode']]
#
#
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = nan
# old insert value nan type is <class 'str'> id is 0
# ##Description = Field exists with missing value##
# new insert value
# value_store_key === > 1
#
#
# ----<<--Ammend base path for ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID ->>-----
# ----<<--actual amended base path ==>/*/*[2]/cac:TaxTotal[1]/cbc:TaxAmount
# ----<<--actual path ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID index == 0
# target element ==>[<Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxAmount at 0x142acc400>]
# >>>>>>target_element.attrib = {'currencyID': 'SGD'}
# >>>>>>target_element.text = 2374.05
#
# ------change attrib------
# ----<<--actual element value==>{'currencyID': 'SGD'} type = <class 'lxml.etree._Attrib'>
# val = SGD
# ----<<--new attribute value==>{'currencyID': ''}
#
#
# ]]]]]]]]]]]]]]]]]base_path_each_path == base_path_field_1]]]]]]]]]]]]]]]]]]
# each path = ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID
# /*/*[2]/cac:TaxTotal[1]/cbc:TaxAmount
# %%%%%%%%%%%%%%%%
#
# <<<<last>>>
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = 1000
# value_store_key === > 2
#
#
# ----<<--Ammend base path for ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount ->>-----
# ----<<--actual amended base path ==>/*/*[2]/cac:TaxTotal[1]/cbc:TaxAmount
# ----<<--actual path ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount index == 1
#
# ------change element------
# ----<<--actual element text==>2374.05
# ----<<--new element text==>1000
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = USD
# value_store_key === > 3
#
#
# ----<<--Ammend base path for ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID ->>-----
# ----<<--actual amended base path ==>/*/*[2]/cac:TaxTotal[2]/cbc:TaxAmount
# ----<<--actual path ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID index == 2
# target element ==>[<Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxAmount at 0x142acd780>]
# >>>>>>target_element.attrib = {'currencyID': 'USD'}
# >>>>>>target_element.text = 2374.05
#
# ------change attrib------
# ----<<--actual element value==>{'currencyID': 'USD'} type = <class 'lxml.etree._Attrib'>
# val = USD
# ----<<--new attribute value==>{'currencyID': 'USD'}
#
#
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = 600
# value_store_key === > 4
#
#
# ----<<--Ammend base path for ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount ->>-----
# ----<<--actual amended base path ==>/*/*[2]/cac:TaxTotal[2]/cbc:TaxAmount
# ----<<--actual path ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount index == 3
#
# ------change element------
# ----<<--actual element text==>2374.05
# ----<<--new element text==>600
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = USD
# value_store_key === > 5
#
#
# ----<<--just change straight away ubl:CreditNote / cbc:DocumentCurrencyCode index == 4->>
#
#
# ===============
# acutal path : /*/*[2]/cbc:DocumentCurrencyCode
#
#
# target element [<Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}DocumentCurrencyCode at 0x142acf080>]
# ------change element------
#
# ------change element------
# ----<<--actual element text==>USD
# ----<<--new element text==>USD
#
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = SGD
# value_store_key === > 6
#
#
# ----<<--just change straight away ubl:CreditNote / cbc:TaxCurrencyCode index == 5->>
#
#
# ===============
# acutal path : /*/*[2]/cbc:TaxCurrencyCode
#
#
# target element [<Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142acef40>]
# ------change element------
#
# ------change element------
# ----<<--actual element text==>SGD
# ----<<--new element text==>SGD
#
#
#
# 6
#
# [nan, 1000, 'USD', 600, 'USD', 'SGD']
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-038_Test_case_215_2_Conditional Input Validation.xml
# ############=================############
# TEST CAES ID 216
# ############=================############
# using /Users/cheongray/iras_api_clean_1/sample_xml_files/sample_4.xml
#
# ----
# --profile--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}ProfileID at 0x142acde40> element text ->urn:fdc:peppol.eu:2017:poacc:billing:01:1.0
#
# ----
# ----
# ----
# --customisation--
#
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CustomizationID at 0x142ace140> element text ->urn:peppol:pint:billing-1@sg-1:LocalTaxInvoice:sg:1.0
#
# ----
# ----
#  216
# ------------
# [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount'], ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 'ubl:CreditNote / cbc:DocumentCurrencyCode', 'ubl:CreditNote / cbc:TaxCurrencyCode']]
#
#
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = nan
# value_store_key === > 1
#
#
# ----<<--Ammend base path for ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID ->>-----
# ----<<--actual amended base path ==>/*/*[2]/cac:TaxTotal[1]/cbc:TaxAmount
# ----<<--actual path ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID index == 0
# target element ==>[<Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxAmount at 0x142acf880>]
# >>>>>>target_element.attrib = {'currencyID': 'SGD'}
# >>>>>>target_element.text = 2374.05
#
# ------change attrib------
# ----<<--actual element value==>{'currencyID': 'SGD'} type = <class 'lxml.etree._Attrib'>
# val = SGD
# ----<<--new attribute value==>{'currencyID': 'nan'}
#
#
# ]]]]]]]]]]]]]]]]]base_path_each_path == base_path_field_1]]]]]]]]]]]]]]]]]]
# each path = ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID
# /*/*[2]/cac:TaxTotal[1]/cbc:TaxAmount
# %%%%%%%%xpath find/*/*[2]/cac:TaxTotal[1]/cbc:TaxAmount %%%%%%%%
#
# Targeting element......
# %%%%%%%% current attrib {'currencyID': 'nan'} %%%%%%%%
# %%%%%%%% new  attrib {} %%%%%%%%
# <<<<last>>>
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = 1000
# value_store_key === > 2
#
#
# ----<<--Ammend base path for ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount ->>-----
# ----<<--actual amended base path ==>/*/*[2]/cac:TaxTotal[1]/cbc:TaxAmount
# ----<<--actual path ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount index == 1
#
# ------change element------
# ----<<--actual element text==>2374.05
# ----<<--new element text==>1000
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = USD
# value_store_key === > 3
#
#
# ----<<--Ammend base path for ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID ->>-----
# ----<<--actual amended base path ==>/*/*[2]/cac:TaxTotal[2]/cbc:TaxAmount
# ----<<--actual path ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID index == 2
# target element ==>[<Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxAmount at 0x142acf980>]
# >>>>>>target_element.attrib = {'currencyID': 'USD'}
# >>>>>>target_element.text = 2374.05
#
# ------change attrib------
# ----<<--actual element value==>{'currencyID': 'USD'} type = <class 'lxml.etree._Attrib'>
# val = USD
# ----<<--new attribute value==>{'currencyID': 'USD'}
#
#
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = 600
# value_store_key === > 4
#
#
# ----<<--Ammend base path for ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount ->>-----
# ----<<--actual amended base path ==>/*/*[2]/cac:TaxTotal[2]/cbc:TaxAmount
# ----<<--actual path ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount index == 3
#
# ------change element------
# ----<<--actual element text==>2374.05
# ----<<--new element text==>600
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = USD
# value_store_key === > 5
#
#
# ----<<--just change straight away ubl:CreditNote / cbc:DocumentCurrencyCode index == 4->>
#
#
# ===============
# acutal path : /*/*[2]/cbc:DocumentCurrencyCode
#
#
# target element [<Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}DocumentCurrencyCode at 0x142acf280>]
# ------change element------
#
# ------change element------
# ----<<--actual element text==>USD
# ----<<--new element text==>USD
#
# +++++++++++++++++++++++++
# +++++++++++++++++++++++++
# ---------------
#
# insert value = SGD
# value_store_key === > 6
#
#
# ----<<--just change straight away ubl:CreditNote / cbc:TaxCurrencyCode index == 5->>
#
#
# ===============
# acutal path : /*/*[2]/cbc:TaxCurrencyCode
#
#
# target element [<Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142acde80>]
# ------change element------
#
# ------change element------
# ----<<--actual element text==>SGD
# ----<<--new element text==>SGD
#
#
#
# 6
#
# [nan, 1000, 'USD', 600, 'USD', 'SGD']
# writing /Users/cheongray/iras_api_clean_1/2_Conditional_Validation/xml_files_for_2_Conditional Input Validation/IRASC5-038_Test_case_216_2_Conditional Input Validation.xml

# %%
def process_xml_files_in_folder_Invoice_ID(folder_path,elements_to_remove):
    check_how_many_removed = []
    remove_from_root = []
    xml_files = glob.glob(os.path.join(folder_path, '*.xml'))
    for index_file,xml_file in enumerate(xml_files):
        name = xml_file.split('/')[-1]
        for e in elements_to_remove:
            
            if name in e:
                file_name = e[0]
#                 xpath_target = e[-2]
                xpath_find = e[1]
                f_p = e[-1]
                tree_temp = etree.parse(f_p)
                r_h = proper_mapping_final(f_p)
                if xpath_find in r_h:
                    xpath_target = r_h[xpath_find]
                    target_root = tree_temp.getroot()
                    element = target_root.xpath(xpath_target,namespaces=namespace_map)[0]
                    print(f'file name {file_name}')
                    print(f'element text {element.text}')
                    if element.getparent() is not None:
                        print('++++++')
                        element.getparent().remove(element)
                        print(element)
                        check_how_many_removed.append(xml_file)
                        print('     ')

                    else:
                        remove_from_root.append(xpath_find)
                        target_root.remove(element)
                    tree = etree.ElementTree(target_root)
                    tree.write(xml_file, encoding='utf-8', xml_declaration=True)
                    continue
            else:
                continue
                
    return check_how_many_removed

check_num = process_xml_files_in_folder_Invoice_ID(folder_name,elements_to_remove)
# Out:
# file name IRASC5-023_Test_case_93_2_Conditional Input Validation.xml
# element text M2-1234567-K
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CompanyID at 0x142ae9240>
#
# file name IRASC5-023_Test_case_98_2_Conditional Input Validation.xml
# element text M2-1234567-K
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CompanyID at 0x136f7f900>
#
# file name IRASC5-023_Test_case_103_2_Conditional Input Validation.xml
# element text M2-1234567-K
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CompanyID at 0x142aeb7c0>
#
# file name IRASC5-014_Test_case_15_2_Conditional Input Validation.xml
# element text SGD
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142b36180>
#
# file name IRASC5-032_Test_case_118_2_Conditional Input Validation.xml
# element text 199700100R
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CompanyID at 0x136f7f700>
#
# file name IRASC5-014_Test_case_23_2_Conditional Input Validation.xml
# element text SGD
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142ae9240>
#
# file name IRASC5-032_Test_case_113_2_Conditional Input Validation.xml
# element text 199700100R
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CompanyID at 0x142b34f80>
#
# file name IRASC5-023_Test_case_68_2_Conditional Input Validation.xml
# element text M2-1234567-K
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CompanyID at 0x142aea2c0>
#
# file name IRASC5-014_Test_case_31_2_Conditional Input Validation.xml
# element text SGD
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142b34c00>
#
# file name IRASC5-014_Test_case_56_2_Conditional Input Validation.xml
# element text SGD
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142ae9300>
#
# file name IRASC5-032_Test_case_128_2_Conditional Input Validation.xml
# element text 199700100R
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CompanyID at 0x142aeb940>
#
# file name IRASC5-032_Test_case_123_2_Conditional Input Validation.xml
# element text 199700100R
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CompanyID at 0x136f7ff40>
#
# file name IRASC5-014_Test_case_7_2_Conditional Input Validation.xml
# element text SGD
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142b37240>
#
# file name IRASC5-014_Test_case_48_2_Conditional Input Validation.xml
# element text SGD
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142ae9580>
#
# file name IRASC5-014_Test_case_24_2_Conditional Input Validation.xml
# element text SGD
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x136f7ff40>
#
# file name IRASC5-032_Test_case_143_2_Conditional Input Validation.xml
# element text 199700100R
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CompanyID at 0x142ae9240>
#
# file name IRASC5-014_Test_case_64_2_Conditional Input Validation.xml
# element text SGD
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142ae8240>
#
# file name IRASC5-014_Test_case_8_2_Conditional Input Validation.xml
# element text SGD
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142aeb0c0>
#
# file name IRASC5-023_Test_case_88_2_Conditional Input Validation.xml
# element text M2-1234567-K
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CompanyID at 0x142ae9580>
#
# file name IRASC5-023_Test_case_83_2_Conditional Input Validation.xml
# element text M2-1234567-K
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CompanyID at 0x142b35440>
#
# file name IRASC5-023_Test_case_78_2_Conditional Input Validation.xml
# element text M2-1234567-K
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CompanyID at 0x142ae9240>
#
# file name IRASC5-023_Test_case_73_2_Conditional Input Validation.xml
# element text M2-1234567-K
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CompanyID at 0x136f7f640>
#
# file name IRASC5-014_Test_case_40_2_Conditional Input Validation.xml
# element text SGD
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x137ceaec0>
#
# file name IRASC5-032_Test_case_108_2_Conditional Input Validation.xml
# element text 199700100R
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CompanyID at 0x136f7f900>
#
# file name IRASC5-032_Test_case_133_2_Conditional Input Validation.xml
# element text 199700100R
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CompanyID at 0x136f7ff40>
#
# file name IRASC5-032_Test_case_138_2_Conditional Input Validation.xml
# element text 199700100R
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}CompanyID at 0x142b06640>
#
# file name IRASC5-014_Test_case_16_2_Conditional Input Validation.xml
# element text SGD
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142b34c00>
#
# file name IRASC5-014_Test_case_32_2_Conditional Input Validation.xml
# element text SGD
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142ae9240>
#
# file name IRASC5-014_Test_case_39_2_Conditional Input Validation.xml
# element text SGD
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142b37240>
#
# file name IRASC5-014_Test_case_55_2_Conditional Input Validation.xml
# element text SGD
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x136f7ff40>
#
# file name IRASC5-014_Test_case_47_2_Conditional Input Validation.xml
# element text SGD
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142ae93c0>
#
# file name IRASC5-014_Test_case_63_2_Conditional Input Validation.xml
# element text SGD
# ++++++
# <Element {urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2}TaxCurrencyCode at 0x142aeb880>

# %%
to_skip_for_manual_fix = []
for i in check_num:
    a= i.split('Test_case')
    to_skip_for_manual_fix.append(int(a[1].split('_')[1]))

# %%
to_skip_for_manual_fix
# Out:
# [93,
#  98,
#  103,
#  15,
#  118,
#  23,
#  113,
#  68,
#  31,
#  56,
#  128,
#  123,
#  7,
#  48,
#  24,
#  143,
#  64,
#  8,
#  88,
#  83,
#  78,
#  73,
#  40,
#  108,
#  133,
#  138,
#  16,
#  32,
#  39,
#  55,
#  47,
#  63]

# %%
total_cases = [i for i in range(1,769)]

# %%
to_manual_fix = [item for item in total_cases if item not in to_skip_for_manual_fix]

# %%
import numpy as np

array = np.array(to_manual_fix )
folder_name = '/Users/cheongray/iras_api_make_xml/store_manual_fix_files'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
new_file_path = os.path.join(folder_name, 'foramt_validation_manual_fix_files.txt')

# Save the array to a text file
np.savetxt(new_file_path, array, fmt='%d')

# %%
filefolderpath = folder_name
c=0
xml_files = glob.glob(os.path.join(filefolderpath, '*.xml'))
for xml in xml_files:
    c+=1
    print(xml)

# %%
c
# Out:
# 0

# %%
# def p2(folder_path,elements_to_remove):
#     check_how_many_removed = []
#     remove_from_root = []
#     xml_files = glob.glob(os.path.join(folder_path, '*.xml'))
#     c=0
#     for index_file,xml_file in enumerate(xml_files):
#         print(xml_file)
#         c+=1
#     return c
   
# c=p2(folder_name,elements_to_remove)
