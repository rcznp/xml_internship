# %%
import pandas as pd
import re
from lxml import etree
import shutil
import os
import math
import copy
import glob
import numpy as np

# %%
#since i use back three
def read_xml_file(file_path_xml):
    result_xml_dict={}
    tree = etree.parse(file_path_xml)
    target_root = tree.getroot()
#     pattern = r'\{.*?\}'
    for element in target_root.iter():
        if element.attrib:
            xpath_base = get_element_xpath(element)
            for e,val in element.attrib.items():
                xpath = xpath_base + ' / ' + '@' + e
#                 print(f'-->{xpath}')
                result_xml_dict[xpath] = tree.getpath(element)
        else:
            xpath = get_element_xpath(element)
            result_xml_dict[xpath] = tree.getpath(element)
    return result_xml_dict
        
def get_element_full_path(tree,element):
    return tree.getpath(element)

def read_xml_file_2(file_path_xml):
    tree = etree.parse(file_path_xml)
    target_root = tree.getroot()
    for element in target_root.iter():
        xpath = tree.getpath(element)
        print(f"XPath: {xpath}")
def load_base_value_iden(file_path):
    if os.path.exists(file_path):
        
        # File exists, load the variable from the file
        if os.path.getsize(file_path) > 0:
                    # File is not empty, load the variable from the file
            with open(file_path, 'r') as file:
                
                variable_loaded = file.read().strip()
#                 print('loading')
#                 print(variable_loaded)
        else:
            # File exists but is empty, initialize with a default value
            variable_loaded = "11e1d6e4-74ba-49cc-9b55-1"
    else:
        # File does not exist, create the file and write the variable to it
#         print('+++++')
        print('creating file...')
        variable_to_store = "11e1d6e4-74ba-49cc-9b55-1"
        with open(file_path, 'w') as file:
            file.write(variable_to_store)
        variable_loaded = variable_to_store
        
    return variable_loaded
def save_base_value_iden(file_path,variable_to_store):
    
    # Write the variable to the file
    with open(file_path, 'w') as file:
        file.write(variable_to_store)
def increment_value_iden(value,file_path):

    str_last = value.split('-')[-1]
    last= int(str_last)
    last+=1
    
    exclude_last = value.split('-')[:-1]
    temp = '-'.join(exclude_last)

    new_identifier = temp + '-' + str(last)
    
    if os.path.exists(file_path):
        with open(file_path, 'w') as file:
            variable_to_store = new_identifier
#             print('writing')
#             print(variable_to_store)
            file.write(variable_to_store)
    else:
        print('load base value first')
def adjust_identifier(root_copy,filepath_base_identifier):
    base_identifier = load_base_value_iden(filepath_base_identifier)

    for index,e in enumerate(root_copy.iter()):
        if index == 10:#rsender identifier:
            e.text = base_identifier
            increment_value_iden(base_identifier,filepath_base_identifier)
def extract_out_second_half(actual_xpath):#to be attachrd to path_base
    temp = actual_xpath.split('/')[-1]
    return temp
def handle_multiple(current_test_case,test_case_id,r_h,target_root):
    print(f' {test_case_id}  ')
    
    hold_1 = prepare_data_for_multiple(current_test_case)
    print('------------')
    print(hold_1)
    print('   ')
    field_1 = hold_1[0][0]
    base_path_field_1 = handle_base_path(field_1)
    
    
    print('------------')
    print('   ')
    temp_base_path = base_path_field_1
    for index,each_case in enumerate(hold_1):
        path_base = temp_base_path + f'[{index+1}]' + '/'
        for each_path in each_case:
            base_path_each_path = handle_base_path(each_path)
            if base_path_each_path == base_path_field_1:
                
                print('   ')
                print(f'----<<--Ammend base path for {each_path} ->>-----')
                if each_path in r_h:
                    actual_xpath = r_h[each_path]
                    temp = extract_out_second_half(actual_xpath)
                    path_base_final = path_base + temp
                    print(f'----<<--actual amended path ==>{path_base_final}')
                    target_element = target_root.xpath(path_base_final,namespaces = namespace_map)
                    print(f'----<<--actual element==>{target_element}')
                    print('   ')
                    print(f'----<<--actual path {each_path}')
                    if '@' in each_path:
                        print('   ')
                        print('------change attrib------')
                        if len(target_element)>0:
                            print(f'----<<--actual element value==>{target_element[0].attrib}')
                            print('   ')
                        else:
                             print(f'--cannot get--<<--{each_path} | {target_element} is empty ')
                    else:
                        print('   ')
                        print('------change element------')
                        if len(target_element)>0:
                            print(f'----<<--actual element text==>{target_element[0].text}')
                        else:
                             print(f'---cannot get-<<--{each_path} | {target_element} is empty ')
                    print('   ')
            else:#base_path_each_path != base_path_field_1:
                print('   ')
                print(f'----<<--just change straight away {each_path} ->>')
                print('   ')
                if '@' in each_path:
                    print('   ')
                    print('------change attrib------')
                    print('   ')
                else:
                    print('   ')
                    print('------change element------')
                    print('   ')
                
                
    print('   ')
    print('------------')
    print('   ')
def handle_base_path(s):
    start = r_h[s]
#     print(f'start {start}')
    a= start
    specific_elem = a.split('/')[-1]
#     print(f'specific elem{specific_elem}')
    temp = a.split('/')[:-1]
#     print('temp',temp)
    temp_a = '/'.join(temp)
#     print('temp_a',temp_a)

    temp_b = temp[-1].split('[')[0]
    temp_c = temp
    temp_c[-1] = temp_b
    temp_d = '/'.join(temp_c)
#     print('temp_d',temp_d)
#     print('   ')
    return temp_d
            
def evaluate_if_got_multiple(current_test_case):
    occur_again = False
    for index,fields in enumerate(current_test_case):
        xpath_find = fields[0].strip()
        if index == 0:
            field_one = xpath_find
        if (xpath_find == field_one) and index != 0:
            occur_again = True
            return True
    return occur_again
def prepare_data_for_multiple(current_test_case):
    holding = []
    for index,fields in enumerate(current_test_case):
        
        path_to_store = fields[0]

        if index == 0:
            temp = []
            field_one = path_to_store
            temp.append(path_to_store)
            
        elif (path_to_store == field_one) and (index != 0):
            holding.append(temp)
            temp = []

        
            temp.append(path_to_store)
        else:
#             print('  ----  ')
#             print('    ')
#             print(temp)
#             print('  ----  ')
#             print('    ')
            temp.append(path_to_store)
    holding.append(temp)
    return holding
def fix_space_typo(temp):
    temp_2 = temp.split("/")
    for index,i in enumerate(temp_2):
        temp_2[index] = i.strip()
    temp_3 = ' / '.join(temp_2)
    return temp_3

# %%
sheet_name = '4_Format Validation'
folder_path = '/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_' + sheet_name

#error prone files from 3_code validation
fils_to_fix_path = '/Users/cheongray/iras_api_make_xml/store_manual_fix_files/foramt_validation_manual_fix_files.txt'
with open(fils_to_fix_path, 'r') as file:
    lines_array = file.readlines()

problems = [int(line.strip()) for line in lines_array]

# %%
def get_id(xml_file):
    temp = xml_file.split('/')[-1]
    temp_2 = temp.split('_Test_case_')[-1].split('_')[0]
    return temp_2
def process_xml_files_3(folder_path):
    c=0
    map_to_values ={}#so can overwrite the dirty files in the oirinal 3_condtionial
    check_how_many_removed = []
    xml_files = glob.glob(os.path.join(folder_path, '*.xml'))
    for file in xml_files:
        test_id = get_id(file)
        if int(test_id) in problems:
            c+=1
            map_to_values[test_id] = file
    return map_to_values

# %%
mtv = process_xml_files_3(folder_path)

# %%
def check_xpath_exists(invoice_dict,xpath):
    if xpath in invoice_dict:
        return True
    else:
        return False
def insert_invoice_dict(invoice_dict_xpath,insert_value,xpath_exists):
    if not xpath_exists:
        invoice_dict[xpath] = insert_value
    else:
        invoice_dict[xpath].append(inse)
    

def get_mapping_for_xml_invoice(file_path_of_sample_xml):

    namespace_map = {
        'sb': 'http://www.unece.org/cefact/namespaces/StandardBusinessDocumentHeader',
        'xs': 'http://www.w3.org/2001/XMLSchema',
        'cac': 'urn:oasis:names:specification:ubl:schema:xsd:CommonAggregateComponents-2',
        'cbc': 'urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2',
        'ubl': 'urn:oasis:names:specification:ubl:schema:xsd:Invoice-2',
        'xsi': "http://www.w3.org/2001/XMLSchema-instance",
        'xsd':"http://www.w3.org/2001/XMLSchema",
        'udt':"urn:un:unece:uncefact:data:specification:UnqualifiedDataTypesSchemaModule:2" ,
        'qdt':"urn:oasis:names:specification:ubl:schema:xsd:QualifiedDatatypes-2",
        'ext':"urn:oasis:names:specification:ubl:schema:xsd:CommonExtensionComponents-2",
        'ccts':"urn:un:unece:uncefact:documentation:2"
    #     'xmlns' : "urn:oasis:names:specification:ubl:schema:xsd:Invoice-2"
    }
    tree = etree.parse(file_path_of_sample_xml)
    target_root = tree.getroot()
    # format_key_map = []
    invoice_dict={}
    for element in target_root.iter():
        if isinstance(element, etree._Comment):
            continue
        ancestors = [e.tag for e in element.iterancestors()][::-1] + [element.tag]

        string_ancestors = [e if isinstance(e, str) else str(e) for e in ancestors]

        path = ' / '.join(string_ancestors)
        for prefix, uri in namespace_map.items():
            path = path.replace('{' + uri + '}', prefix + ':')
        if 'sb:StandardBusinessDocument / ubl:Invoice / ' in path:
            path = path.replace('sb:StandardBusinessDocument / ', '')
            if element.attrib:
                xpath_base = path
#                 print(f'==={1}======')
#                 print(element)
#                 print(element.text)
#                 print(xpath_base)
#                 print('============')
#                 print('           ')
                xpath_exists = check_xpath_exists(invoice_dict,xpath_base)
                if not xpath_exists:
                    invoice_dict[xpath_base] = [tree.getpath(element)]
                    
                else:
                    invoice_dict[xpath_base].append(tree.getpath(element))
                for e,val in element.attrib.items():
                    xpath = xpath_base + ' / ' + '@' + e
                    if xpath in invoice_dict:
                         invoice_dict[xpath].append(tree.getpath(element))
                    else:
                        invoice_dict[xpath] = [tree.getpath(element)]
            else:                
#                 print(f'={909}=={1}======')
#                 print(element)
                
#                 print(element.text)
#                 print(xpath_base)
#                 print(path)
#                 print('============')
#                 print('           ')
                insert_value = tree.getpath(element)
                xpath_exists = check_xpath_exists(invoice_dict,path)
                if not xpath_exists:
                    invoice_dict[path] = [insert_value]
                else:
                    invoice_dict[path].append(insert_value)

        else:
            if element.attrib:
#                 print(f'==={2}======')
#                 print(element)
#                 print(path)
#                 print('============')
#                 print('           ')
                xpath_base = get_element_xpath(element)
                invoice_dict[xpath_base] = tree.getpath(element)
                for e,val in element.attrib.items():
                    xpath = xpath_base + ' / ' + '@' + e
    #                 print(f'-->{xpath}')


                    invoice_dict[xpath] = [tree.getpath(element)]
            else:
#                 print(f'==={2}======')
#                 print(element)
#                 print(path)
#                 print('============')
#                 print('           ')
                xpath = get_element_xpath(element)#defined on top
                

                
                insert_value = tree.getpath(element)
#                 print('=========')
#                 print(element)
#                 print(xpath)
#                 print(f'insert val = {insert_value}')
#                 print('============')
#                 print('           ')
                xpath_exists = check_xpath_exists(invoice_dict,xpath)
                if not xpath_exists:
                    invoice_dict[xpath] = [insert_value]
                else:
                    
                    invoice_dict[xpath].append(insert_value)
    r_h = invoice_dict
    return r_h
def get_mapping_for_xml_credit(file_path_of_sample_xml):

    namespace_map = {
        'sb': 'http://www.unece.org/cefact/namespaces/StandardBusinessDocumentHeader',
        'xs': 'http://www.w3.org/2001/XMLSchema',
        'cac': 'urn:oasis:names:specification:ubl:schema:xsd:CommonAggregateComponents-2',
        'cbc': 'urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2',
        'ubl': 'urn:oasis:names:specification:ubl:schema:xsd:CreditNote-2',
        'xsi': "http://www.w3.org/2001/XMLSchema-instance",
        'xsd':"http://www.w3.org/2001/XMLSchema",
        'udt':"urn:un:unece:uncefact:data:specification:UnqualifiedDataTypesSchemaModule:2" ,
        'qdt':"urn:oasis:names:specification:ubl:schema:xsd:QualifiedDatatypes-2",
        'ext':"urn:oasis:names:specification:ubl:schema:xsd:CommonExtensionComponents-2",
        'ccts':"urn:un:unece:uncefact:documentation:2" 
    }
    tree = etree.parse(file_path_of_sample_xml)
    target_root = tree.getroot()
    # format_key_map = []
    invoice_dict={}
    for element in target_root.iter():
        if isinstance(element, etree._Comment):
            continue
        ancestors = [e.tag for e in element.iterancestors()][::-1] + [element.tag]

        string_ancestors = [e if isinstance(e, str) else str(e) for e in ancestors]

        path = ' / '.join(string_ancestors)
        for prefix, uri in namespace_map.items():
            path = path.replace('{' + uri + '}', prefix + ':')
        if 'sb:StandardBusinessDocument / ubl:CreditNote / ' in path:

            path = path.replace('sb:StandardBusinessDocument / ', '')
            if element.attrib:
                xpath_base = path
#                 print(f'==={1}======')
#                 print(element)
#                 print(element.text)
#                 print(xpath_base)
#                 print('============')
#                 print('           ')
                xpath_exists = check_xpath_exists(invoice_dict,xpath_base)
                if not xpath_exists:
                    invoice_dict[xpath_base] = [tree.getpath(element)]
                    
                else:
                    invoice_dict[xpath_base].append(tree.getpath(element))
                for e,val in element.attrib.items():
                    xpath = xpath_base + ' / ' + '@' + e
                    if xpath in invoice_dict:
                         invoice_dict[xpath].append(tree.getpath(element))
                    else:
                        invoice_dict[xpath] = [tree.getpath(element)]
            else:                
#                 print(f'={909}=={1}======')
#                 print(element)
                
#                 print(element.text)
#                 print(xpath_base)
#                 print(path)
#                 print('============')
#                 print('           ')
                insert_value = tree.getpath(element)
                xpath_exists = check_xpath_exists(invoice_dict,path)
                if not xpath_exists:
                    invoice_dict[path] = [insert_value]
                else:
                    invoice_dict[path].append(insert_value)

        else:
            if element.attrib:
#                 print(f'==={2}======')
#                 print(element)
#                 print(path)
#                 print('============')
#                 print('           ')
                xpath_base = get_element_xpath(element)
                invoice_dict[xpath_base] = tree.getpath(element)
                for e,val in element.attrib.items():
                    xpath = xpath_base + ' / ' + '@' + e
    #                 print(f'-->{xpath}')


                    invoice_dict[xpath] = [tree.getpath(element)]
            else:
#                 print(f'==={2}======')
#                 print(element)
#                 print(path)
#                 print('============')
#                 print('           ')
                xpath = get_element_xpath(element)#defined on top
                

                
                insert_value = tree.getpath(element)
#                 print('=========')
#                 print(element)
#                 print(xpath)
#                 print(f'insert val = {insert_value}')
#                 print('============')
#                 print('           ')
                xpath_exists = check_xpath_exists(invoice_dict,xpath)
                if not xpath_exists:
                    invoice_dict[xpath] = [insert_value]
                else:
                    
                    invoice_dict[xpath].append(insert_value)
    r_h = invoice_dict
    return r_h






def credit_or_invoice(file_path):
#     print('********')
#     print(file_path)
    tree = etree.parse(file_path)
    target_root = tree.getroot()
    for index,e in enumerate(target_root.iter()):
        if index ==11:
            if 'Credit' in e.text:
                return 'credit'
            elif 'Invoice' in e.text:
                return 'invoice'
            else:
                return 'undefined'
def proper_mapping_final(file_path):

    if credit_or_invoice(file_path) == 'credit':
        r_h = get_mapping_for_xml_credit(file_path)
        return r_h
    elif credit_or_invoice(file_path) == 'invoice':
        r_h = get_mapping_for_xml_invoice(file_path)
        return r_h
    else:
        return None
def get_element_xpath(element):
    path = [element.tag.split('}')[-1]]
    for parent in element.iterancestors():
        parent_tag = parent.tag.split('}')[-1]  
        path.insert(0, parent_tag)
    return ' / '.join(path)

# %%
file_path = r"/Users/cheongray/iras_api_pytest_1/AP_SP_files/AP_SP_FINAL_5.xlsx"#download to here from emails

# path_to_sample_xml_files_folder = r"/Users/cheongray/iras_api_clean_1/sample_xml_files"


df_s = pd.read_excel(file_path, sheet_name=sheet_name)
df_s_temp = df_s.copy()
df_s_temp['Test Case ID'] = df_s_temp.index.astype(float)#REMINDER,now test_case_id is 1_1
# df_s_peppol = df_s_temp[(df_s_temp['Standard'] == 'PEPPOL') & (df_s_temp['Document Type'] == 'Invoice')].copy()
# df_s_peppol['Test Case ID'] = df_s_peppol['Test Case ID'] + 1
# df_s_peppol.reset_index(drop=True)
df_s_temp['Test Case ID'] = df_s_temp['Test Case ID'] + 1

# %%
df_s_temp_subset = df_s_temp.copy()

unique_descriptions = set()

target_elements_syn = []

for index,row in df_s_temp_subset.iterrows():
    filled_columns = row.dropna().index
    test_case_id = f' {index}'
    descript = row['Test Case Description']
#     print(f'Test case {index+1}')
#     print(f'Test case description : {descript}')
    unique_descriptions.add(descript)#just to build function_mapping
    temp={}
    temp['Rule ID'] = row['Rule ID']
    temp['Standard'] = row['Standard']
    temp['Document Type'] = row['Document Type']
    temp['BIS/PINT'] = row['BIS/PINT']
    temp['Test Case ID'] = int(row['Test Case ID'])
    id = int(row['Test Case ID'])
    temp['descript'] = descript
    temp['Expected Result'] = row['Expected Result Response (for 400 response)']
    temp['Status'] = row['Expected Result']
    temp['Fields'] = []
    temp['Sample'] = row['Sample']
#     temp['Helper'] = row['Helper']
    for i, col in enumerate(filled_columns, start=1):
        field_name = f'Field {i}'
        
        if field_name in df_s_temp_subset.columns:
            # Process the data as needed
#             print(f'Column: {field_name}, Value: {row[field_name]}')
   
            
            temp_2 = [] #each field will be one array,can do dict but mor steps when want access
            if not pd.isna(row[field_name]):
                field_value = field_name + ' Value'
                field_name_insert = fix_space_typo(row[field_name])
                temp_2.append(field_name_insert)
                temp_2.append(row[field_value])
                temp['Fields'].append(temp_2)
        
    target_elements_syn.append(temp)

# %%
path_to_sample_xml_files_folder = '/Users/cheongray/iras_api_pytest_1/sample_xml_files'
#gets the needed files for 2_Conditional_Input_Validation
file_paths_xml_files = {}

for i,test_case in enumerate(target_elements_syn):
    
    sample_to_use = test_case['Sample']
    
    num = sample_to_use.split(' ')[-1]
    file_name = 'sample' + '_' + num + '.xml'
    
    path_to_sample_xml_files = path_to_sample_xml_files_folder + '/' + file_name
    
    file_paths_xml_files[sample_to_use] = path_to_sample_xml_files

# %%
# tree = etree.parse('/Users/cheongray/iras_api_pytest_1/sample_xml_files/sample_2.xml')
# target_root = tree.getroot()
# for t in target_root.iter():
#     print(t)
#     print(get_element_xpath(t))
#     print('=============')
#     print('         ')

# %%
work_st_1 = []
for testcase in target_elements_syn:
    if testcase['Test Case ID'] in problems:
        temp=[]
        temp.append(testcase['Test Case ID'])
        temp.append(testcase['Fields'])
        temp.append(testcase['Sample'])
        temp.append(testcase['descript'])
        work_st_1.append(temp)

# %%
work_st_2 = []
for index_work_1,e in enumerate(work_st_1):
    if int(work_st_1[index_work_1][0]) in problems:
        work_st_2.append(work_st_1[index_work_1])

# %%
for test_case in work_st_2:
    t = test_case[0]
    f_p = mtv[str(t)]
    print(f_p)
# Out:
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_2_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_3_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_4_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_6_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_7_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_8_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_10_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_11_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_12_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_14_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_15_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_16_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_18_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_19_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_20_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_22_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_23_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_24_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_26_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_27_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_28_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_30_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_31_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_32_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_34_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_35_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_36_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_38_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_39_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_40_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_42_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_43_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_44_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_46_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_47_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_48_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_50_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_51_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_52_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_54_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_55_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_56_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_58_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_59_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_60_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_62_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_63_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_64_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_66_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_67_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_68_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_70_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_71_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_72_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_74_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_75_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_76_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_78_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_79_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_80_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_82_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_83_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_84_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_86_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_87_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_88_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_90_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_91_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_92_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_94_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_95_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_96_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_98_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_99_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_100_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_102_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_103_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_104_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_106_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_107_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_108_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_110_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_111_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_112_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_114_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_115_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_116_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_118_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_119_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_120_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_122_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_123_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_124_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_126_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_127_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_128_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_129_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_130_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_131_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_132_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_133_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_134_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_135_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_136_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_137_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_138_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_139_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_140_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_141_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_142_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_143_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_144_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_145_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_146_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_147_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_148_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_149_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_150_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_151_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-080_Test_case_152_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_153_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_154_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_155_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_156_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_157_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_158_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_159_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_160_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_161_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_162_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_163_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_164_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_165_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_166_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_167_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_168_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_169_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_170_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_171_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_172_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_173_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_174_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_175_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-081_Test_case_176_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_177_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_178_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_179_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_180_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_181_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_182_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_183_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_184_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_185_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_186_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_187_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_188_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_189_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_190_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_191_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_192_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_193_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_194_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_195_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_196_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_197_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_198_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_199_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-082_Test_case_200_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_201_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_202_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_203_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_204_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_205_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_206_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_207_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_208_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_209_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_210_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_211_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_212_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_213_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_214_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_215_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_216_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_217_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_218_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_219_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_220_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_221_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_222_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_223_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-083_Test_case_224_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_225_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_226_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_227_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_228_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_229_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_230_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_231_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_232_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_233_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_234_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_235_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_236_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_237_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_238_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_239_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_240_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_241_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_242_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_243_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_244_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_245_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_246_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_247_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-084_Test_case_248_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_249_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_250_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_251_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_252_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_253_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_254_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_255_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_256_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_257_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_258_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_259_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_260_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_261_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_262_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_263_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_264_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_265_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_266_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_267_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_268_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_269_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_270_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_271_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-085_Test_case_272_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_273_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_274_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_275_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_276_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_277_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_278_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_279_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_280_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_281_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_282_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_283_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_284_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_285_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_286_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_287_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_288_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_289_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_290_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_291_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_292_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_293_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_294_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_295_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-086_Test_case_296_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_298_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_299_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_300_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_302_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_303_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_304_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_306_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_307_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_308_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_310_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_311_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_312_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_314_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_315_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_316_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_318_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_319_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_320_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_322_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_323_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_324_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_326_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_327_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-087_Test_case_328_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_330_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_331_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_332_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_334_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_335_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_336_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_338_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_339_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_340_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_342_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_343_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_344_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_346_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_347_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_348_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_350_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_351_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_352_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_354_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_355_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_356_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_358_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_359_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-088_Test_case_360_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_362_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_363_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_364_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_366_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_367_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_368_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_370_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_371_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_372_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_374_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_375_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_376_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_378_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_379_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_380_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_382_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_383_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_384_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_386_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_387_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_388_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_390_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_391_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-089_Test_case_392_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-090_Test_case_394_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-090_Test_case_395_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-090_Test_case_396_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-090_Test_case_398_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-090_Test_case_399_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-090_Test_case_400_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-090_Test_case_402_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-090_Test_case_403_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-090_Test_case_404_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-090_Test_case_406_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-090_Test_case_407_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-090_Test_case_408_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-090_Test_case_410_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-090_Test_case_411_4_Format Validation.xml
# ...
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-098_Test_case_642_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-098_Test_case_643_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-098_Test_case_644_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-098_Test_case_646_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-098_Test_case_647_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-098_Test_case_648_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-098_Test_case_650_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-098_Test_case_651_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-098_Test_case_652_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-098_Test_case_654_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-098_Test_case_655_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-098_Test_case_656_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_658_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_659_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_660_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_662_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_663_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_664_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_666_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_667_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_668_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_670_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_671_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_672_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_674_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_675_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_676_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_678_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_679_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_680_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_682_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_683_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_684_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_686_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_687_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-099_Test_case_688_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_689_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_690_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_691_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_692_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_693_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_694_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_695_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_696_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_697_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_698_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_699_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_700_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_701_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_702_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_703_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_704_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_705_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_706_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_707_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_708_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_709_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_710_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_711_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_712_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_713_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_714_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_715_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_716_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_717_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_718_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_719_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_720_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_721_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_722_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_723_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_724_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_725_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_726_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_727_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-0100_Test_case_728_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_729_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_730_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_731_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_732_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_733_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_734_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_735_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_736_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_737_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_738_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_739_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_740_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_741_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_742_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_743_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_744_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_745_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_746_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_747_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_748_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_749_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_750_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_751_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_752_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_753_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_754_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_755_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_756_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_757_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_758_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_759_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_760_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_761_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_762_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_763_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_764_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_765_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_766_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_767_4_Format Validation.xml
# /Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_768_4_Format Validation.xml

# %%
# def flip_bit(value):#just in caes so never go out of lenght 2 range
#     return value ^ 1

# %%
work_st_2
# Out:
# [[2,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 200],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [3,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 200.15],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [4,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 200.167],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [6,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 200],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [7,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 200.15],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [8,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 200.167],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [10,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 200],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [11,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 200.15],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [12,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 200.167],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [14,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 200],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [15,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 200.15],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [16,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 200.167],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [18,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 200],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [19,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 200.15],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [20,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 200.167],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [22,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 200],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [23,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 200.15],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [24,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 200.167],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [26,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 200],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [27,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 200.15],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [28,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 200.167],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [30,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 200],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [31,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 200.15],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [32,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 200.167],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [34,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 345],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [35,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 345.23],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [36,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 345.987],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [38,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 345],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [39,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 345.23],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [40,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 345.987],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [42,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 345],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [43,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 345.23],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [44,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 345.987],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [46,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 345],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [47,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 345.23],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [48,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:Amount', 345.987],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [50,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 345],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [51,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 345.23],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [52,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 345.987],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [54,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 345],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [55,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 345.23],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [56,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 345.987],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [58,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 345],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [59,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 345.23],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [60,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 345.987],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [62,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 345],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [63,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 345.23],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [64,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:Amount', 345.987],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [66,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 10000],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [67,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 10000.82],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [68,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 10000.853],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [70,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 10000],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [71,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 10000.82],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [72,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 10000.853],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [74,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 10000],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [75,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 10000.82],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [76,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 10000.853],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [78,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 10000],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [79,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 10000.82],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [80,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 10000.853],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [82,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 10000],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [83,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 10000.82],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [84,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 10000.853],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [86,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 10000],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [87,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 10000.82],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [88,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 10000.853],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [90,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 10000],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [91,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 10000.82],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [92,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 10000.853],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [94,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 10000],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [95,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 10000.82],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [96,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 10000.853],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'false']],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [98,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 15000],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [99,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 15000.23],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [100,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 15000.987],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [102,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 15000],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [103,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 15000.23],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [104,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 15000.987],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [106,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 15000],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [107,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 15000.23],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [108,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 15000.987],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [110,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 15000],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [111,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 15000.23],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [112,
#   [['ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount', 15000.987],
#    ['ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [114,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 15000],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [115,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 15000.23],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [116,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 15000.987],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [118,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 15000],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [119,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 15000.23],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [120,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 15000.987],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [122,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 15000],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [123,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 15000.23],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [124,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 15000.987],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [126,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 15000],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [127,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 15000.23],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [128,
#   [['ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount', 15000.987],
#    ['ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator', 'true']],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [129,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 2567]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [130,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 2567.84]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [131,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 2567.841]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [132,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 2567]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [133,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 2567.84]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [134,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 2567.841]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [135,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 2567]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [136,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 2567.84]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [137,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 2567.841]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [138,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 2567]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [139,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 2567.84]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [140,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 2567.841]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [141,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 2567]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [142,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 2567.84]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [143,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 2567.841]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [144,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 2567]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [145,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 2567.84]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [146,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 2567.841]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [147,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 2567]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [148,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 2567.84]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [149,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 2567.841]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [150,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 2567]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [151,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 2567.84]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [152,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 2567.841]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [153,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 90],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 135],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 2',
#   'Field exists with no decimal place'],
#  [154,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 90.15],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 135.75],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 2',
#   'Field exists with 2 decimal places'],
#  [155,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 90.158],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 135.758],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 2',
#   'Field exists with more than 2 decimal places'],
#  [156,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 90],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 135],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 2',
#   'Field exists with no decimal place'],
#  [157,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 90.15],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 135.75],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 2',
#   'Field exists with 2 decimal places'],
#  [158,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 90.158],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 135.758],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 2',
#   'Field exists with more than 2 decimal places'],
#  [159,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 90],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 135],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 2',
#   'Field exists with no decimal place'],
#  [160,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 90.15],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 135.75],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 2',
#   'Field exists with 2 decimal places'],
#  [161,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 90.158],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 135.758],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 2',
#   'Field exists with more than 2 decimal places'],
#  [162,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 90],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 135],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 2',
#   'Field exists with no decimal place'],
#  [163,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 90.15],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 135.75],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 2',
#   'Field exists with 2 decimal places'],
#  [164,
#   [['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 90.158],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount', 135.758],
#    ['ubl:Invoice / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 2',
#   'Field exists with more than 2 decimal places'],
#  [165,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 90],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 135],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 4',
#   'Field exists with no decimal place'],
#  [166,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 90.15],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 135.75],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 4',
#   'Field exists with 2 decimal places'],
#  [167,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 90.158],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 135.758],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 4',
#   'Field exists with more than 2 decimal places'],
#  [168,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 90],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 135],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 4',
#   'Field exists with no decimal place'],
#  [169,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 90.15],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 135.75],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 4',
#   'Field exists with 2 decimal places'],
#  [170,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 90.158],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 135.758],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 4',
#   'Field exists with more than 2 decimal places'],
#  [171,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 90],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 135],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 4',
#   'Field exists with no decimal place'],
#  [172,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 90.15],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 135.75],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 4',
#   'Field exists with 2 decimal places'],
#  [173,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 90.158],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 135.758],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 4',
#   'Field exists with more than 2 decimal places'],
#  [174,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 90],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 135],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 4',
#   'Field exists with no decimal place'],
#  [175,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 90.15],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 135.75],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 4',
#   'Field exists with 2 decimal places'],
#  [176,
#   [['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 90.158],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'SGD'],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount', 135.758],
#    ['ubl:CreditNote / cac:TaxTotal / cbc:TaxAmount / @currencyID', 'USD']],
#   'Sample 4',
#   'Field exists with more than 2 decimal places'],
#  [177,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [178,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000.99]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [179,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000.994]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [180,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [181,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000.99]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [182,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000.994]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [183,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [184,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000.99]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [185,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000.994]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [186,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [187,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000.99]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [188,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000.994]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [189,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [190,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000.99]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [191,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000.994]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [192,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [193,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000.99]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [194,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000.994]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [195,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [196,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000.99]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [197,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000.994]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [198,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [199,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000.99]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [200,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxableAmount',
#     500000.994]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [201,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount', 695]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [202,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount', 695.01]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [203,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount', 695.017]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [204,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount', 695]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [205,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount', 695.01]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [206,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount', 695.017]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [207,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount', 695]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [208,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount', 695.01]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [209,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount', 695.017]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [210,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount', 695]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [211,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount', 695.01]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [212,
#   [['ubl:Invoice / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount', 695.017]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [213,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount', 695]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [214,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount',
#     695.01]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [215,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount',
#     695.017]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [216,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount', 695]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [217,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount',
#     695.01]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [218,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount',
#     695.017]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [219,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount', 695]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [220,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount',
#     695.01]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [221,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount',
#     695.017]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [222,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount', 695]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [223,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount',
#     695.01]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [224,
#   [['ubl:CreditNote / cac:TaxTotal / cac:TaxSubtotal / cbc:TaxAmount',
#     695.017]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [225,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:LineExtensionAmount', 1670]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [226,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670.55]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [227,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670.559]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [228,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:LineExtensionAmount', 1670]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [229,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670.55]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [230,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670.559]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [231,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:LineExtensionAmount', 1670]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [232,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670.55]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [233,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670.559]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [234,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:LineExtensionAmount', 1670]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [235,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670.55]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [236,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670.559]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [237,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [238,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670.55]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [239,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670.559]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [240,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [241,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670.55]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [242,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670.559]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [243,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [244,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670.55]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [245,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670.559]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [246,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [247,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670.55]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [248,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:LineExtensionAmount',
#     1670.559]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [249,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount', 8950]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [250,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount', 8950.63]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [251,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount',
#     8950.638]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [252,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount', 8950]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [253,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount', 8950.63]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [254,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount',
#     8950.638]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [255,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount', 8950]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [256,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount', 8950.63]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [257,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount',
#     8950.638]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [258,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount', 8950]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [259,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount', 8950.63]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [260,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount',
#     8950.638]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [261,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount', 8950]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [262,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount',
#     8950.63]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [263,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount',
#     8950.638]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [264,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount', 8950]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [265,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount',
#     8950.63]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [266,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount',
#     8950.638]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [267,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount', 8950]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [268,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount',
#     8950.63]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [269,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount',
#     8950.638]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [270,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount', 8950]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [271,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount',
#     8950.63]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [272,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxExclusiveAmount',
#     8950.638]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [273,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount', 9735]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [274,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount', 9735.12]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [275,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount',
#     9735.128]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [276,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount', 9735]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [277,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount', 9735.12]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [278,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount',
#     9735.128]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [279,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount', 9735]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [280,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount', 9735.12]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [281,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount',
#     9735.128]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [282,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount', 9735]],
#   'Sample 1',
#   'Field exists with no decimal place'],
#  [283,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount', 9735.12]],
#   'Sample 1',
#   'Field exists with 2 decimal places'],
#  [284,
#   [['ubl:Invoice / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount',
#     9735.128]],
#   'Sample 1',
#   'Field exists with more than 2 decimal places'],
#  [285,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount', 9735]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [286,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount',
#     9735.12]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [287,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount',
#     9735.128]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [288,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount', 9735]],
#   'Sample 3',
#   'Field exists with no decimal place'],
#  [289,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount',
#     9735.12]],
#   'Sample 3',
#   'Field exists with 2 decimal places'],
#  [290,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount',
#     9735.128]],
#   'Sample 3',
#   'Field exists with more than 2 decimal places'],
#  [291,
#   [['ubl:CreditNote / cac:LegalMonetaryTotal / cbc:TaxInclusiveAmount', 9735]],
#   'Sample 3',
# ...
#     2000],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-incl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-incl-gst' and Document Description = amount with no decimal place"],
#  [727,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     2000.01],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-incl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-incl-gst' and Document Description = amount with 2 decimal places"],
#  [728,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     2000.011],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-incl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-incl-gst' and Document Description = amount with more than 2 decimal places"],
#  [729,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal']],
#   'Sample 12',
#   "Document Type Code != 'sgdtotal-excl-gst'"],
#  [730,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     'Seventy Four Thousand Dollars'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 2',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = text"],
#  [731,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 2',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with no decimal place"],
#  [732,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000.37],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 2',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with 2 decimal places"],
#  [733,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000.378],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 2',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with more than 2 decimal places"],
#  [734,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74001],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal']],
#   'Sample 12',
#   "Document Type Code != 'sgdtotal-excl-gst'"],
#  [735,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     'Seventy Four Thousand Dollars'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 2',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = text"],
#  [736,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 2',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with no decimal place"],
#  [737,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000.28],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 2',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with 2 decimal places"],
#  [738,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74001.0053333333],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 2',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with more than 2 decimal places"],
#  [739,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74002],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal']],
#   'Sample 12',
#   "Document Type Code != 'sgdtotal-excl-gst'"],
#  [740,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     'Seventy Four Thousand Dollars'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 2',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = text"],
#  [741,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 2',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with no decimal place"],
#  [742,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000.28],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 2',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with 2 decimal places"],
#  [743,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74001.5723333333],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 2',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with more than 2 decimal places"],
#  [744,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74003],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal']],
#   'Sample 12',
#   "Document Type Code != 'sgdtotal-excl-gst'"],
#  [745,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     'Seventy Four Thousand Dollars'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 2',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = text"],
#  [746,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 2',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with no decimal place"],
#  [747,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000.28],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 2',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with 2 decimal places"],
#  [748,
#   [['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74002.1393333333],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:Invoice / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 2',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with more than 2 decimal places"],
#  [749,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74004],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal']],
#   'Sample 13',
#   "Document Type Code != 'sgdtotal-excl-gst'"],
#  [750,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     'Seventy Four Thousand Dollars'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = text"],
#  [751,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with no decimal place"],
#  [752,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000.28],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with 2 decimal places"],
#  [753,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74002.7063333333],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with more than 2 decimal places"],
#  [754,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74005],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal']],
#   'Sample 13',
#   "Document Type Code != 'sgdtotal-excl-gst'"],
#  [755,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     'Seventy Four Thousand Dollars'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = text"],
#  [756,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with no decimal place"],
#  [757,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000.28],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with 2 decimal places"],
#  [758,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74003.2733333333],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with more than 2 decimal places"],
#  [759,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74006],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal']],
#   'Sample 13',
#   "Document Type Code != 'sgdtotal-excl-gst'"],
#  [760,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     'Seventy Four Thousand Dollars'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = text"],
#  [761,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with no decimal place"],
#  [762,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000.28],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with 2 decimal places"],
#  [763,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74003.8403333333],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with more than 2 decimal places"],
#  [764,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74007],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal']],
#   'Sample 13',
#   "Document Type Code != 'sgdtotal-excl-gst'"],
#  [765,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     'Seventy Four Thousand Dollars'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = text"],
#  [766,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with no decimal place"],
#  [767,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74000.28],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with 2 decimal places"],
#  [768,
#   [['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription',
#     74004.4073333333],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode',
#     'sgdtotal-excl-gst'],
#    ['ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID', 'SGD']],
#   'Sample 4',
#   "Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with more than 2 decimal places"]]

# %%
def flip_bit(value):#just in caes so never go out of lenght 2 range
    return value ^ 1
namespace_map = {
    'sb': 'http://www.unece.org/cefact/namespaces/StandardBusinessDocumentHeader',
    'xs': 'http://www.w3.org/2001/XMLSchema',
    'cac': 'urn:oasis:names:specification:ubl:schema:xsd:CommonAggregateComponents-2',
    'cbc': 'urn:oasis:names:specification:ubl:schema:xsd:CommonBasicComponents-2',
    }
for test_case in work_st_2:
    
    desc = test_case[3]
    print('============Description===============')
    print(desc)
    print('           ')
    print('            ')
    sample_number = test_case[2]
    test_case_id = test_case[0]
    f_p = mtv[str(test_case_id)]
    print(f'===={sample_number}====={f_p}={test_case_id}==')
    a = proper_mapping_final(f_p)
    holding_set = []
    values = []
    pos_temp = 0#used to access the first/second value
    pos_temp_storage={}#each field will have a flip bit
    key_storage_for_pos_temp_storage = []
    for i,path in enumerate(test_case[1]):
    
        pos_temp_storage[path[0]] = pos_temp
        key_storage_for_pos_temp_storage.append(path[0]+str(i))

    print(pos_temp_storage)
    for i,path in enumerate(test_case[1]):
        unique_iden = str(i)
        xpaths = a[path[0]]
        value = path[1]
        if i == 0 and str(value) == 'nan':
            if 'missing value' or 'No instance' in desc:
                print(f'chaniging value for {test_case_id} ')
                value = ''
        values.append(value)
#         print( ' xpaths')
#         print(xpaths)
#         print('========')
        if isinstance(xpaths, str):
            if xpaths not in holding_set:
                holding_set.append(xpaths)
        else:
            key = pos_temp_storage[path[0]]
#             print(xpaths[pos_temp_storage[path[0]+unique_iden]])
            print(key)
            print(xpaths)
            if len(xpaths) <2:
                holding_set.append(xpaths[0])
            else:
                holding_set.append(xpaths[key])
            pos_temp_storage[path[0]] = flip_bit(key)
#         print('&&&&&&&')
#         print(pos_temp_storage)
#         print('&&&&&&&&')
            
            
#     print('         ')
        
#     print('    holding set      ')
#     print(holding_set)
    tree = etree.parse(f_p)
    target_root = tree.getroot()
    print('   ')
    original_tree_copy = copy.deepcopy(target_root)
    for index_values,path_to_insert in enumerate(holding_set):
        attrib_yes = False
        key_for_pos_temp_storage = key_storage_for_pos_temp_storage[index_values]
        
        element =  original_tree_copy.xpath(path_to_insert,namespaces = namespace_map)[0]
        insert_value = str(values[index_values])
        if '@' in key_for_pos_temp_storage :#attribute
                attrib_yes = True
                for key, value in element.attrib.items():
                    print(f'----<<--actual element value==>{element.attrib}')
                    element.attrib[key] = insert_value
                    print(f'----<<--new element value==>{element.attrib}')
        
        if '@' not in key_for_pos_temp_storage:
            print(f'original text {element.text} index values={index_values} {insert_value}')
            element.text =insert_value
            print(f'new text {element.text}')
            print('   ')
            
        if index_values == 0:
            if insert_value == 'nan' or insert_value == '':
                if 'does not exist' in desc:
                    #remove attribute/element
                    print('does not exist in description....')
                    if not attrib_yes:
                        print('%%%%%%%% Remove element %%%%%%%%')
                        parent = element.getparent()

                        if element.getparent() is not None:
                            element.getparent().remove(element)

                        print('------------')
                    else:
                        print('%%%%%%%% Remove attrib %%%%%%%%')
                        del element.attrib[key_attrib]
                
            
    tree = etree.ElementTree(original_tree_copy)
    filepath = mtv[str(test_case_id)]
    tree.write(filepath, encoding='utf-8', xml_declaration=True)
    
    print('============')
# Out:
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_2_4_Format Validation.xml=2==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200 index values=0 200
# new text 200
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_3_4_Format Validation.xml=3==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200.15 index values=0 200.15
# new text 200.15
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_4_4_Format Validation.xml=4==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200.167 index values=0 200.167
# new text 200.167
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_6_4_Format Validation.xml=6==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200 index values=0 200
# new text 200
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_7_4_Format Validation.xml=7==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200.15 index values=0 200.15
# new text 200.15
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_8_4_Format Validation.xml=8==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200.167 index values=0 200.167
# new text 200.167
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_10_4_Format Validation.xml=10==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200 index values=0 200
# new text 200
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_11_4_Format Validation.xml=11==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200.15 index values=0 200.15
# new text 200.15
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_12_4_Format Validation.xml=12==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200.167 index values=0 200.167
# new text 200.167
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_14_4_Format Validation.xml=14==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200 index values=0 200
# new text 200
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_15_4_Format Validation.xml=15==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200.15 index values=0 200.15
# new text 200.15
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_16_4_Format Validation.xml=16==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200.167 index values=0 200.167
# new text 200.167
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_18_4_Format Validation.xml=18==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200 index values=0 200
# new text 200
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_19_4_Format Validation.xml=19==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200.15 index values=0 200.15
# new text 200.15
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_20_4_Format Validation.xml=20==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200.167 index values=0 200.167
# new text 200.167
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_22_4_Format Validation.xml=22==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200 index values=0 200
# new text 200
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_23_4_Format Validation.xml=23==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200.15 index values=0 200.15
# new text 200.15
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_24_4_Format Validation.xml=24==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200.167 index values=0 200.167
# new text 200.167
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_26_4_Format Validation.xml=26==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200 index values=0 200
# new text 200
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_27_4_Format Validation.xml=27==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200.15 index values=0 200.15
# new text 200.15
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_28_4_Format Validation.xml=28==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200.167 index values=0 200.167
# new text 200.167
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_30_4_Format Validation.xml=30==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200 index values=0 200
# new text 200
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_31_4_Format Validation.xml=31==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200.15 index values=0 200.15
# new text 200.15
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-076_Test_case_32_4_Format Validation.xml=32==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 200.167 index values=0 200.167
# new text 200.167
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_34_4_Format Validation.xml=34==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345 index values=0 345
# new text 345
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_35_4_Format Validation.xml=35==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345.23 index values=0 345.23
# new text 345.23
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_36_4_Format Validation.xml=36==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345.987 index values=0 345.987
# new text 345.987
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_38_4_Format Validation.xml=38==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345 index values=0 345
# new text 345
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_39_4_Format Validation.xml=39==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345.23 index values=0 345.23
# new text 345.23
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_40_4_Format Validation.xml=40==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345.987 index values=0 345.987
# new text 345.987
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_42_4_Format Validation.xml=42==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345 index values=0 345
# new text 345
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_43_4_Format Validation.xml=43==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345.23 index values=0 345.23
# new text 345.23
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_44_4_Format Validation.xml=44==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345.987 index values=0 345.987
# new text 345.987
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_46_4_Format Validation.xml=46==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345 index values=0 345
# new text 345
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_47_4_Format Validation.xml=47==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345.23 index values=0 345.23
# new text 345.23
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_48_4_Format Validation.xml=48==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345.987 index values=0 345.987
# new text 345.987
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_50_4_Format Validation.xml=50==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345 index values=0 345
# new text 345
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_51_4_Format Validation.xml=51==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345.23 index values=0 345.23
# new text 345.23
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_52_4_Format Validation.xml=52==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345.987 index values=0 345.987
# new text 345.987
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_54_4_Format Validation.xml=54==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345 index values=0 345
# new text 345
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_55_4_Format Validation.xml=55==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345.23 index values=0 345.23
# new text 345.23
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_56_4_Format Validation.xml=56==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345.987 index values=0 345.987
# new text 345.987
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_58_4_Format Validation.xml=58==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345 index values=0 345
# new text 345
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_59_4_Format Validation.xml=59==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345.23 index values=0 345.23
# new text 345.23
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_60_4_Format Validation.xml=60==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345.987 index values=0 345.987
# new text 345.987
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_62_4_Format Validation.xml=62==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345 index values=0 345
# new text 345
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_63_4_Format Validation.xml=63==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345.23 index values=0 345.23
# new text 345.23
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-077_Test_case_64_4_Format Validation.xml=64==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:Amount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:Amount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 345.987 index values=0 345.987
# new text 345.987
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_66_4_Format Validation.xml=66==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000 index values=0 10000
# new text 10000
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_67_4_Format Validation.xml=67==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000.82 index values=0 10000.82
# new text 10000.82
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_68_4_Format Validation.xml=68==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000.853 index values=0 10000.853
# new text 10000.853
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_70_4_Format Validation.xml=70==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000 index values=0 10000
# new text 10000
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_71_4_Format Validation.xml=71==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000.82 index values=0 10000.82
# new text 10000.82
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_72_4_Format Validation.xml=72==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000.853 index values=0 10000.853
# new text 10000.853
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_74_4_Format Validation.xml=74==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000 index values=0 10000
# new text 10000
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_75_4_Format Validation.xml=75==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000.82 index values=0 10000.82
# new text 10000.82
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_76_4_Format Validation.xml=76==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000.853 index values=0 10000.853
# new text 10000.853
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_78_4_Format Validation.xml=78==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000 index values=0 10000
# new text 10000
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_79_4_Format Validation.xml=79==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000.82 index values=0 10000.82
# new text 10000.82
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_80_4_Format Validation.xml=80==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000.853 index values=0 10000.853
# new text 10000.853
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_82_4_Format Validation.xml=82==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000 index values=0 10000
# new text 10000
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_83_4_Format Validation.xml=83==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000.82 index values=0 10000.82
# new text 10000.82
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_84_4_Format Validation.xml=84==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000.853 index values=0 10000.853
# new text 10000.853
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_86_4_Format Validation.xml=86==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000 index values=0 10000
# new text 10000
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_87_4_Format Validation.xml=87==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000.82 index values=0 10000.82
# new text 10000.82
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_88_4_Format Validation.xml=88==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000.853 index values=0 10000.853
# new text 10000.853
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_90_4_Format Validation.xml=90==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000 index values=0 10000
# new text 10000
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_91_4_Format Validation.xml=91==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000.82 index values=0 10000.82
# new text 10000.82
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_92_4_Format Validation.xml=92==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000.853 index values=0 10000.853
# new text 10000.853
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_94_4_Format Validation.xml=94==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000 index values=0 10000
# new text 10000
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_95_4_Format Validation.xml=95==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000.82 index values=0 10000.82
# new text 10000.82
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 3=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-078_Test_case_96_4_Format Validation.xml=96==
# {'ubl:CreditNote / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:CreditNote / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 10000.853 index values=0 10000.853
# new text 10000.853
#
# original text false index values=1 false
# new text false
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_98_4_Format Validation.xml=98==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 15000 index values=0 15000
# new text 15000
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_99_4_Format Validation.xml=99==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 15000.23 index values=0 15000.23
# new text 15000.23
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_100_4_Format Validation.xml=100==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 15000.987 index values=0 15000.987
# new text 15000.987
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with no decimal place
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_102_4_Format Validation.xml=102==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 15000 index values=0 15000
# new text 15000
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with 2 decimal places
#
#
# ====Sample 1=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-079_Test_case_103_4_Format Validation.xml=103==
# {'ubl:Invoice / cac:AllowanceCharge / cbc:BaseAmount': 0, 'ubl:Invoice / cac:AllowanceCharge / cbc:ChargeIndicator': 0}
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:BaseAmount']
# 0
# ['/*/*[2]/cac:AllowanceCharge/cbc:ChargeIndicator']
#
# original text 15000.23 index values=0 15000.23
# new text 15000.23
#
# original text true index values=1 true
# new text true
#
# ============
# ============Description===============
# Field exists with more than 2 decimal places
#
#
# ...
#
# original text 230.0 index values=0 74000
# new text 74000
#
# original text sgdtotal-excl-gst index values=1 sgdtotal-excl-gst
# new text sgdtotal-excl-gst
#
# original text SGD index values=2 SGD
# new text SGD
#
# ============
# ============Description===============
# Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with 2 decimal places
#
#
# ====Sample 4=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_757_4_Format Validation.xml=757==
# {'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID': 0}
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:DocumentDescription']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:DocumentTypeCode']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:ID']
#
# original text 230.0 index values=0 74000.28
# new text 74000.28
#
# original text sgdtotal-excl-gst index values=1 sgdtotal-excl-gst
# new text sgdtotal-excl-gst
#
# original text SGD index values=2 SGD
# new text SGD
#
# ============
# ============Description===============
# Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with more than 2 decimal places
#
#
# ====Sample 4=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_758_4_Format Validation.xml=758==
# {'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID': 0}
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:DocumentDescription']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:DocumentTypeCode']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:ID']
#
# original text 230.0 index values=0 74003.2733333333
# new text 74003.2733333333
#
# original text sgdtotal-excl-gst index values=1 sgdtotal-excl-gst
# new text sgdtotal-excl-gst
#
# original text SGD index values=2 SGD
# new text SGD
#
# ============
# ============Description===============
# Document Type Code != 'sgdtotal-excl-gst'
#
#
# ====Sample 13=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_759_4_Format Validation.xml=759==
# {'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode': 0}
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentDescription']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentTypeCode']
#
# original text 74006 index values=0 74006
# new text 74006
#
# original text sgdtotal index values=1 sgdtotal
# new text sgdtotal
#
# ============
# ============Description===============
# Document Type Code = 'sgdtotal-excl-gst' and Document Description = text
#
#
# ====Sample 4=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_760_4_Format Validation.xml=760==
# {'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID': 0}
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:DocumentDescription']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:DocumentTypeCode']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:ID']
#
# original text 230.0 index values=0 Seventy Four Thousand Dollars
# new text Seventy Four Thousand Dollars
#
# original text sgdtotal-excl-gst index values=1 sgdtotal-excl-gst
# new text sgdtotal-excl-gst
#
# original text SGD index values=2 SGD
# new text SGD
#
# ============
# ============Description===============
# Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with no decimal place
#
#
# ====Sample 4=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_761_4_Format Validation.xml=761==
# {'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID': 0}
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:DocumentDescription']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:DocumentTypeCode']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:ID']
#
# original text 230.0 index values=0 74000
# new text 74000
#
# original text sgdtotal-excl-gst index values=1 sgdtotal-excl-gst
# new text sgdtotal-excl-gst
#
# original text SGD index values=2 SGD
# new text SGD
#
# ============
# ============Description===============
# Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with 2 decimal places
#
#
# ====Sample 4=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_762_4_Format Validation.xml=762==
# {'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID': 0}
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:DocumentDescription']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:DocumentTypeCode']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:ID']
#
# original text 230.0 index values=0 74000.28
# new text 74000.28
#
# original text sgdtotal-excl-gst index values=1 sgdtotal-excl-gst
# new text sgdtotal-excl-gst
#
# original text SGD index values=2 SGD
# new text SGD
#
# ============
# ============Description===============
# Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with more than 2 decimal places
#
#
# ====Sample 4=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_763_4_Format Validation.xml=763==
# {'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID': 0}
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:DocumentDescription']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:DocumentTypeCode']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:ID']
#
# original text 230.0 index values=0 74003.8403333333
# new text 74003.8403333333
#
# original text sgdtotal-excl-gst index values=1 sgdtotal-excl-gst
# new text sgdtotal-excl-gst
#
# original text SGD index values=2 SGD
# new text SGD
#
# ============
# ============Description===============
# Document Type Code != 'sgdtotal-excl-gst'
#
#
# ====Sample 13=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_764_4_Format Validation.xml=764==
# {'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode': 0}
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentDescription']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentTypeCode']
#
# original text 74007 index values=0 74007
# new text 74007
#
# original text sgdtotal index values=1 sgdtotal
# new text sgdtotal
#
# ============
# ============Description===============
# Document Type Code = 'sgdtotal-excl-gst' and Document Description = text
#
#
# ====Sample 4=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_765_4_Format Validation.xml=765==
# {'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID': 0}
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:DocumentDescription']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:DocumentTypeCode']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:ID']
#
# original text 230.0 index values=0 Seventy Four Thousand Dollars
# new text Seventy Four Thousand Dollars
#
# original text sgdtotal-excl-gst index values=1 sgdtotal-excl-gst
# new text sgdtotal-excl-gst
#
# original text SGD index values=2 SGD
# new text SGD
#
# ============
# ============Description===============
# Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with no decimal place
#
#
# ====Sample 4=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_766_4_Format Validation.xml=766==
# {'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID': 0}
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:DocumentDescription']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:DocumentTypeCode']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:ID']
#
# original text 230.0 index values=0 74000
# new text 74000
#
# original text sgdtotal-excl-gst index values=1 sgdtotal-excl-gst
# new text sgdtotal-excl-gst
#
# original text SGD index values=2 SGD
# new text SGD
#
# ============
# ============Description===============
# Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with 2 decimal places
#
#
# ====Sample 4=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_767_4_Format Validation.xml=767==
# {'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID': 0}
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:DocumentDescription']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:DocumentTypeCode']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:ID']
#
# original text 230.0 index values=0 74000.28
# new text 74000.28
#
# original text sgdtotal-excl-gst index values=1 sgdtotal-excl-gst
# new text sgdtotal-excl-gst
#
# original text SGD index values=2 SGD
# new text SGD
#
# ============
# ============Description===============
# Document Type Code = 'sgdtotal-excl-gst' and Document Description = amount with more than 2 decimal places
#
#
# ====Sample 4=====/Users/cheongray/iras_api_clean_1/4_Format_Validation/xml_files_for_4_Format Validation/IRASC5-101_Test_case_768_4_Format Validation.xml=768==
# {'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentDescription': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:DocumentTypeCode': 0, 'ubl:CreditNote / cac:AdditionalDocumentReference / cbc:ID': 0}
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentDescription', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:DocumentDescription']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:DocumentTypeCode', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:DocumentTypeCode']
# 0
# ['/*/*[2]/cac:AdditionalDocumentReference[1]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[2]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[3]/cbc:ID', '/*/*[2]/cac:AdditionalDocumentReference[4]/cbc:ID']
#
# original text 230.0 index values=0 74004.4073333333
# new text 74004.4073333333
#
# original text sgdtotal-excl-gst index values=1 sgdtotal-excl-gst
# new text sgdtotal-excl-gst
#
# original text SGD index values=2 SGD
# new text SGD
#
# ============

# %%
# holding_paths = a['ubl:Invoice / cac:InvoiceLine / cac:Item / cac:ClassifiedTaxCategory / cbc:ID']

# %%
#---end
